# %% [markdown]
# # Imports

# %%
from collections import namedtuple, Counter
from datetime import datetime
import csv

# %% [markdown]
# # Helper functions and CSV file readers as functions

# %%
def cast(data_type, value):
    if data_type == 'DATE':
        return datetime.strptime(value, '%m/%d/%Y')
    elif data_type == 'DATETIME':
        return datetime.strptime(value, '%Y-%m-%dT%H:%M:%SZ')
    elif data_type == 'INT':
        return int(value)
    elif data_type == 'SSN':
        return int(value.replace('-',''))
    else:
        return str(value)

# %%
def personal_info_iterator(filepath):
    with open(filepath) as lines:
        PInfo = namedtuple('PInfo', lines.readline().rstrip("\n").replace(' ','').split(','))
        data_types = ['SSN', 'STR', 'STR', 'STR', 'STR']
        for line in lines: 
            proc_values = [cast(data_type, value) for data_type, value in zip(data_types, line.rstrip("\n").split(','))]
            yield (PInfo(*proc_values))

# %%
def update_status_iterator(filepath):
    with open(filepath) as lines:
        UpdateStatus = namedtuple('UpdateStatus', lines.readline().rstrip("\n").replace(' ','').split(','))
        data_types = ['SSN', 'DATETIME', 'DATETIME']
        for line in lines: 
            proc_values = [cast(data_type, value) for data_type, value in zip(data_types, line.rstrip("\n").split(','))]
            yield (UpdateStatus(*proc_values))

# %%
def emp_status_iterator(filepath):
    with open(filepath) as f:
        lines = csv.reader(f, delimiter=',', quotechar='"')
        EmpStatus = namedtuple('EmpStatus', next(lines))
        data_types = ['STR', 'STR', 'SSN', 'SSN']
        for line in lines: 
            proc_values = [cast(data_type, value) for data_type, value in zip(data_types, line)]
            yield (EmpStatus(*proc_values))

# %%
def vehicles_iterator(filepath):
    with open(filepath) as f:
        lines = csv.reader(f, delimiter=',', quotechar='"')
        Vehicle = namedtuple('Vehicle', next(lines))
        data_types = ['SSN', 'STR', 'STR', 'INT']
        for line in lines: 
            proc_values = [cast(data_type, value) for data_type, value in zip(data_types, line)]
            yield (Vehicle(*proc_values))

# %% [markdown]
# # SSN Details Iterable, aggregates the named tuples into single one

# %%
class SSNDetails:
    def __init__(self,personal_info_file,update_status_file,emp_status_file,vehicles_file):
        self.personal_info_file = personal_info_file
        self.update_status_file = update_status_file
        self.emp_status_file = emp_status_file
        self.vehicles_file = vehicles_file
    
    def __iter__(self):
        return self.SSNIterator(self.personal_info_file,self.update_status_file,self.emp_status_file,
                                self.vehicles_file)
    
    class SSNIterator:
        def __init__(self,personal_info_file,update_status_file,emp_status_file,vehicles_file):
            self.personal_info_iterator = personal_info_iterator(personal_info_file)
            self.update_status_iterator = update_status_iterator(update_status_file)
            self.emp_status_iterator = emp_status_iterator(emp_status_file)
            self.vehicles_iterator = vehicles_iterator(vehicles_file)
            
        def __iter__(self):
            return self
        
        def merge(self,ntuples):
            m = {}
            for i in ntuples:
                m.update(i._asdict())
            Details = namedtuple("Details", m.keys())(*m.values())
            return Details
        
        def __next__(self):
            personal_info_tuple = next(self.personal_info_iterator)
            update_status_tuple = next(self.update_status_iterator)
            emp_status_tuple = next(self.emp_status_iterator)
            vehicles_tuple = next(self.vehicles_iterator)
            return self.merge([personal_info_tuple, update_status_tuple, emp_status_tuple, vehicles_tuple])

# %%
itr = SSNDetails('personal_info.csv','update_status.csv','employment.csv','vehicles.csv' )

# %%
for entry in itr:
    print(entry)
# Out:
# Details(ssn=100539824, first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic', last_updated=datetime.datetime(2017, 10, 7, 0, 14, 42), created=datetime.datetime(2016, 1, 24, 21, 19, 30), employer='Stiedemann-Bailey', department='Research and Development', employee_id=290890771, vehicle_make='Oldsmobile', vehicle_model='Bravada', model_year=1993)
# Details(ssn=101714702, first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao', last_updated=datetime.datetime(2017, 1, 23, 11, 23, 17), created=datetime.datetime(2016, 1, 27, 4, 32, 57), employer='Nicolas and Sons', department='Sales', employee_id=416841359, vehicle_make='Ford', vehicle_model='Mustang', model_year=1997)
# Details(ssn=101840356, first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish', last_updated=datetime.datetime(2017, 10, 4, 11, 21, 30), created=datetime.datetime(2016, 9, 21, 23, 4, 7), employer='Connelly Group', department='Research and Development', employee_id=987952860, vehicle_make='GMC', vehicle_model='Yukon', model_year=2005)
# Details(ssn=104220928, first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi', last_updated=datetime.datetime(2017, 3, 28, 12, 38, 29), created=datetime.datetime(2016, 4, 15, 11, 37, 17), employer='Upton LLC', department='Marketing', employee_id=569817552, vehicle_make='Oldsmobile', vehicle_model='Intrigue', model_year=2000)
# Details(ssn=104847144, first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans', last_updated=datetime.datetime(2018, 2, 19, 1, 34, 33), created=datetime.datetime(2016, 3, 15, 14, 7, 57), employer='Zemlak-Olson', department='Business Development', employee_id=462886707, vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=2008)
# Details(ssn=105275541, first_name='Federico', last_name='Aggett', gender='Male', language='Chinese', last_updated=datetime.datetime(2017, 7, 24, 8, 58, 52), created=datetime.datetime(2016, 7, 23, 17, 58, 35), employer='Kohler, Bradtke and Davis', department='Support', employee_id=800975518, vehicle_make='Ford', vehicle_model='Mustang', model_year=2001)
# Details(ssn=105857486, first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi', last_updated=datetime.datetime(2018, 2, 14, 11, 32, 39), created=datetime.datetime(2016, 12, 15, 5, 46, 43), employer='Roberts, Torphy and Dach', department='Human Resources', employee_id=774895332, vehicle_make='Chrysler', vehicle_model='300', model_year=2008)
# Details(ssn=105915022, first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian', last_updated=datetime.datetime(2018, 3, 24, 14, 29, 33), created=datetime.datetime(2016, 3, 24, 3, 43, 3), employer='Lind-Jast', department='Marketing', employee_id=796418731, vehicle_make='Isuzu', vehicle_model='Hombre Space', model_year=2000)
# Details(ssn=105917777, first_name='Audi', last_name='Roach', gender='Female', language='Estonian', last_updated=datetime.datetime(2017, 5, 11, 1, 48, 32), created=datetime.datetime(2016, 5, 31, 0, 38, 13), employer='Bashirian-Lueilwitz', department='Engineering', employee_id=443328799, vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004)
# Details(ssn=106351938, first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish', last_updated=datetime.datetime(2017, 10, 21, 1, 7, 28), created=datetime.datetime(2016, 9, 8, 4, 2, 12), employer='Windler, Marks and Haley', department='Services', employee_id=546271885, vehicle_make='GMC', vehicle_model='Sonoma Club', model_year=1992)
# Details(ssn=106363293, first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin', last_updated=datetime.datetime(2017, 3, 18, 18, 24, 17), created=datetime.datetime(2016, 5, 16, 21, 21, 36), employer='Leffler-Hahn', department='Accounting', employee_id=315735282, vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008)
# Details(ssn=110843641, first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento', last_updated=datetime.datetime(2017, 9, 4, 19, 2, 3), created=datetime.datetime(2016, 9, 12, 22, 50, 5), employer='Lueilwitz LLC', department='Marketing', employee_id=339146042, vehicle_make='Ford', vehicle_model='Mustang', model_year=1990)
# Details(ssn=111351034, first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz', last_updated=datetime.datetime(2017, 3, 18, 14, 51, 4), created=datetime.datetime(2016, 8, 21, 7, 36, 17), employer='Davis Inc', department='Accounting', employee_id=390400385, vehicle_make='Ford', vehicle_model='Fiesta', model_year=2001)
# Details(ssn=114066912, first_name='Jule', last_name='Velte', gender='Male', language='Dutch', last_updated=datetime.datetime(2018, 2, 5, 20, 48, 34), created=datetime.datetime(2016, 7, 15, 21, 58, 3), employer='Kunze LLC', department='Research and Development', employee_id=782612900, vehicle_make='Aston Martin', vehicle_model='DBS', model_year=2011)
# Details(ssn=114660984, first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian', last_updated=datetime.datetime(2017, 6, 16, 17, 41, 33), created=datetime.datetime(2016, 5, 28, 20, 31, 25), employer='Mayert, Rice and Schmitt', department='Product Management', employee_id=858596488, vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998)
# Details(ssn=114748701, first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic', last_updated=datetime.datetime(2017, 10, 30, 23, 54, 38), created=datetime.datetime(2016, 6, 4, 5, 18, 3), employer='Pouros LLC', department='Legal', employee_id=142589283, vehicle_make='Mercedes-Benz', vehicle_model='CL65 AMG', model_year=2009)
# Details(ssn=116107235, first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari', last_updated=datetime.datetime(2017, 3, 10, 0, 31, 43), created=datetime.datetime(2016, 10, 17, 2, 11, 26), employer='Pfannerstill Group', department='Research and Development', employee_id=431532437, vehicle_make='Bugatti', vehicle_model='Veyron', model_year=2009)
# Details(ssn=116774915, first_name='Herold', last_name='Fearon', gender='Male', language='Italian', last_updated=datetime.datetime(2017, 11, 21, 14, 25, 11), created=datetime.datetime(2016, 7, 3, 3, 55, 39), employer='Ryan Group', department='Sales', employee_id=88274517, vehicle_make='Buick', vehicle_model='Rainier', model_year=2004)
# Details(ssn=117396617, first_name='Auroora', last_name='Yong', gender='Female', language='Swahili', last_updated=datetime.datetime(2017, 9, 1, 11, 58, 21), created=datetime.datetime(2016, 12, 1, 10, 11, 17), employer='Ritchie-Pagac', department='Business Development', employee_id=380095184, vehicle_make='Scion', vehicle_model='tC', model_year=2008)
# Details(ssn=117779748, first_name='Lucien', last_name='Smalman', gender='Male', language='Hebrew', last_updated=datetime.datetime(2017, 2, 18, 23, 9, 25), created=datetime.datetime(2016, 2, 2, 15, 41, 42), employer='Schmeler and Sons', department='Research and Development', employee_id=623275199, vehicle_make='Audi', vehicle_model='S6', model_year=2009)
# Details(ssn=117786202, first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish', last_updated=datetime.datetime(2017, 11, 2, 2, 26, 10), created=datetime.datetime(2016, 4, 18, 0, 25, 1), employer='Kerluke-Dibbert', department='Services', employee_id=905121197, vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2007)
# Details(ssn=118210357, first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian', last_updated=datetime.datetime(2017, 12, 13, 9, 36, 48), created=datetime.datetime(2016, 10, 24, 3, 40, 22), employer='Hane-Klocko', department='Human Resources', employee_id=272946273, vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1992)
# Details(ssn=118957100, first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian', last_updated=datetime.datetime(2017, 4, 25, 7, 54, 46), created=datetime.datetime(2016, 1, 29, 12, 5, 28), employer='Ernser LLC', department='Services', employee_id=76466085, vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# Details(ssn=119078817, first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian', last_updated=datetime.datetime(2017, 12, 24, 15, 31, 5), created=datetime.datetime(2016, 12, 6, 14, 16, 59), employer='Terry LLC', department='Accounting', employee_id=704864087, vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2005)
# Details(ssn=120335535, first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi', last_updated=datetime.datetime(2017, 11, 11, 8, 53, 11), created=datetime.datetime(2016, 7, 10, 20, 49), employer='Rolfson, Price and Crooks', department='Business Development', employee_id=770255816, vehicle_make='Isuzu', vehicle_model='Trooper', model_year=1997)
# Details(ssn=120984054, first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh', last_updated=datetime.datetime(2017, 12, 1, 17, 30, 55), created=datetime.datetime(2016, 7, 23, 15, 52, 53), employer='Romaguera, Welch and Haley', department='Engineering', employee_id=146523887, vehicle_make='Acura', vehicle_model='RL', model_year=2003)
# Details(ssn=121983948, first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian', last_updated=datetime.datetime(2017, 8, 23, 16, 0, 57), created=datetime.datetime(2016, 6, 26, 23, 46, 48), employer='Paucek, Huels and Bauch', department='Accounting', employee_id=211452824, vehicle_make='Pontiac', vehicle_model='Montana', model_year=2002)
# Details(ssn=123053229, first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian', last_updated=datetime.datetime(2017, 8, 16, 12, 8, 6), created=datetime.datetime(2016, 10, 23, 13, 32, 13), employer='Hayes-Trantow', department='Support', employee_id=72855255, vehicle_make='Jaguar', vehicle_model='X-Type', model_year=2003)
# Details(ssn=123622832, first_name='Kare', last_name='Barhams', gender='Female', language='Tajik', last_updated=datetime.datetime(2017, 9, 11, 0, 2, 44), created=datetime.datetime(2016, 10, 22, 16, 14, 5), employer='Cruickshank, Legros and Keebler', department='Research and Development', employee_id=571590433, vehicle_make='Cadillac', vehicle_model='Catera', model_year=1999)
# Details(ssn=123883381, first_name='Christiane', last_name='Hynes', gender='Female', language='Danish', last_updated=datetime.datetime(2017, 2, 21, 16, 37, 38), created=datetime.datetime(2016, 1, 30, 23, 42, 36), employer='Mueller-Rath', department='Human Resources', employee_id=58069298, vehicle_make='Ford', vehicle_model='Mustang', model_year=1989)
# Details(ssn=125079434, first_name='Florella', last_name='Mathevon', gender='Female', language='Armenian', last_updated=datetime.datetime(2017, 2, 7, 14, 36, 31), created=datetime.datetime(2016, 7, 8, 17, 46, 23), employer='Schumm, Schumm and Reichert', department='Engineering', employee_id=733839744, vehicle_make='Lexus', vehicle_model='RX', model_year=2010)
# Details(ssn=127492473, first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole', last_updated=datetime.datetime(2017, 8, 31, 10, 3, 3), created=datetime.datetime(2016, 8, 29, 18, 48, 40), employer='Tromp-Leffler', department='Support', employee_id=26267170, vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2004)
# Details(ssn=127528001, first_name='Wilona', last_name='Noirel', gender='Female', language='Aymara', last_updated=datetime.datetime(2017, 1, 12, 9, 42, 31), created=datetime.datetime(2016, 10, 9, 1, 14, 36), employer='Wolf LLC', department='Engineering', employee_id=538370994, vehicle_make='Porsche', vehicle_model='Cayenne', model_year=2008)
# Details(ssn=127684232, first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic', last_updated=datetime.datetime(2017, 3, 20, 6, 5, 42), created=datetime.datetime(2016, 8, 19, 16, 32, 21), employer='Kulas-Corwin', department='Sales', employee_id=780632027, vehicle_make='Scion', vehicle_model='xB', model_year=2004)
# Details(ssn=127933548, first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao', last_updated=datetime.datetime(2017, 9, 10, 6, 24, 19), created=datetime.datetime(2016, 7, 23, 1, 30, 3), employer='MacGyver, Wiegand and Grant', department='Product Management', employee_id=774182531, vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=2007)
# Details(ssn=128424599, first_name='Neddy', last_name="O'Griffin", gender='Male', language='Croatian', last_updated=datetime.datetime(2017, 1, 29, 20, 31, 15), created=datetime.datetime(2016, 7, 13, 9, 52, 36), employer="Kertzmann-O'Hara", department='Sales', employee_id=448015165, vehicle_make='Chevrolet', vehicle_model='Avalanche 1500', model_year=2006)
# Details(ssn=128530369, first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian', last_updated=datetime.datetime(2017, 8, 10, 21, 18), created=datetime.datetime(2016, 12, 19, 21, 37, 6), employer='Vandervort, Bernier and Morissette', department='Human Resources', employee_id=144998615, vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# Details(ssn=128537952, first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish', last_updated=datetime.datetime(2017, 8, 31, 16, 42, 23), created=datetime.datetime(2016, 7, 29, 3, 46, 26), employer='King-Donnelly', department='Training', employee_id=820573004, vehicle_make='Dodge', vehicle_model='Neon', model_year=1995)
# Details(ssn=128566040, first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian', last_updated=datetime.datetime(2017, 8, 13, 2, 47, 15), created=datetime.datetime(2016, 3, 21, 8, 59, 56), employer='Harris Inc', department='Support', employee_id=537535536, vehicle_make='BMW', vehicle_model='M', model_year=2001)
# Details(ssn=128604388, first_name='Norton', last_name='Shailer', gender='Male', language='Czech', last_updated=datetime.datetime(2017, 1, 3, 20, 33, 45), created=datetime.datetime(2016, 3, 18, 11, 18, 14), employer='Heidenreich, Bergnaum and Smith', department='Training', employee_id=47204163, vehicle_make='Buick', vehicle_model='Skyhawk', model_year=1988)
# Details(ssn=129670291, first_name='Danella', last_name='Linacre', gender='Female', language='Dzongkha', last_updated=datetime.datetime(2017, 2, 11, 10, 18, 21), created=datetime.datetime(2016, 12, 12, 5, 1, 34), employer='Altenwerth-Heidenreich', department='Research and Development', employee_id=583628686, vehicle_make='Lotus', vehicle_model='Esprit', model_year=1993)
# Details(ssn=131814310, first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish', last_updated=datetime.datetime(2018, 3, 21, 12, 2, 31), created=datetime.datetime(2016, 2, 3, 23, 26, 27), employer='Gibson and Sons', department='Sales', employee_id=578173633, vehicle_make='Land Rover', vehicle_model='Range Rover Sport', model_year=2012)
# Details(ssn=132263507, first_name='Shalom', last_name='Arendsen', gender='Male', language='Hindi', last_updated=datetime.datetime(2017, 1, 19, 7, 33, 37), created=datetime.datetime(2016, 5, 20, 1, 41, 54), employer='Rodriguez LLC', department='Legal', employee_id=657310166, vehicle_make='Dodge', vehicle_model='Ramcharger', model_year=1992)
# Details(ssn=134050120, first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino', last_updated=datetime.datetime(2017, 1, 29, 11, 53, 22), created=datetime.datetime(2016, 8, 3, 4, 54, 40), employer='Donnelly-Crooks', department='Human Resources', employee_id=222943669, vehicle_make='BMW', vehicle_model='M5', model_year=2006)
# Details(ssn=135869625, first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz', last_updated=datetime.datetime(2017, 12, 22, 4, 4, 28), created=datetime.datetime(2016, 2, 28, 23, 53, 17), employer='Hyatt LLC', department='Training', employee_id=969647102, vehicle_make='Toyota', vehicle_model='Tundra', model_year=2004)
# Details(ssn=137131889, first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama', last_updated=datetime.datetime(2017, 12, 24, 9, 44, 10), created=datetime.datetime(2016, 3, 1, 19, 9, 29), employer='Schuster Group', department='Research and Development', employee_id=724728604, vehicle_make='Infiniti', vehicle_model='G', model_year=2005)
# Details(ssn=138654579, first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish', last_updated=datetime.datetime(2017, 4, 17, 16, 30, 2), created=datetime.datetime(2016, 12, 17, 7, 7, 47), employer='Homenick-Beer', department='Product Management', employee_id=19334133, vehicle_make='Oldsmobile', vehicle_model='Achieva', model_year=1992)
# Details(ssn=138671198, first_name='Pam', last_name='Tofful', gender='Female', language='Bislama', last_updated=datetime.datetime(2018, 3, 4, 8, 14, 31), created=datetime.datetime(2016, 9, 24, 1, 52, 46), employer='VonRueden-Torphy', department='Business Development', employee_id=106636122, vehicle_make='Lexus', vehicle_model='RX', model_year=2003)
# Details(ssn=138885288, first_name='Joletta', last_name='Babcock', gender='Female', language='Burmese', last_updated=datetime.datetime(2017, 2, 24, 15, 47, 36), created=datetime.datetime(2016, 1, 4, 9, 37, 53), employer='Mohr, Harvey and Mitchell', department='Legal', employee_id=647550101, vehicle_make='Mercury', vehicle_model='Monterey', model_year=2004)
# Details(ssn=139048189, first_name='Stirling', last_name='Creak', gender='Male', language='Italian', last_updated=datetime.datetime(2017, 2, 16, 21, 23, 10), created=datetime.datetime(2016, 5, 24, 4, 10, 50), employer='Keeling-Schroeder', department='Engineering', employee_id=822479019, vehicle_make='Ford', vehicle_model='Escort', model_year=1997)
# Details(ssn=139945865, first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole', last_updated=datetime.datetime(2017, 8, 19, 16, 22, 52), created=datetime.datetime(2016, 9, 10, 21, 9, 28), employer='Gusikowski-Block', department='Legal', employee_id=411454732, vehicle_make='Volkswagen', vehicle_model='Cabriolet', model_year=1990)
# Details(ssn=139996417, first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi', last_updated=datetime.datetime(2018, 1, 17, 17, 51, 12), created=datetime.datetime(2016, 12, 21, 14, 14, 20), employer='Pollich-Heathcote', department='Product Management', employee_id=122844710, vehicle_make='Volvo', vehicle_model='V70', model_year=2002)
# Details(ssn=140339727, first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian', last_updated=datetime.datetime(2017, 9, 21, 23, 4, 48), created=datetime.datetime(2016, 1, 27, 9, 2, 26), employer='Bogisich Inc', department='Human Resources', employee_id=347172919, vehicle_make='Mitsubishi', vehicle_model='Lancer', model_year=2003)
# Details(ssn=140588263, first_name='Tim', last_name='Bergin', gender='Female', language='Maori', last_updated=datetime.datetime(2017, 11, 12, 21, 41, 50), created=datetime.datetime(2016, 12, 14, 20, 27, 22), employer='Gutkowski Inc', department='Engineering', employee_id=834836768, vehicle_make='Volvo', vehicle_model='XC90', model_year=2009)
# Details(ssn=141150543, first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin', last_updated=datetime.datetime(2017, 9, 27, 10, 29, 9), created=datetime.datetime(2016, 7, 17, 22, 40, 37), employer='Greenholt LLC', department='Sales', employee_id=845391800, vehicle_make='Toyota', vehicle_model='Corolla', model_year=2000)
# Details(ssn=141889721, first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana', last_updated=datetime.datetime(2018, 1, 24, 20, 0, 4), created=datetime.datetime(2016, 12, 20, 0, 43, 43), employer='Hartmann Inc', department='Support', employee_id=267276512, vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011)
# Details(ssn=142774616, first_name='Barron', last_name='Victoria', gender='Male', language='Assamese', last_updated=datetime.datetime(2017, 7, 16, 15, 12, 37), created=datetime.datetime(2016, 7, 30, 13, 28, 38), employer='Zboncak-Gulgowski', department='Marketing', employee_id=50368584, vehicle_make='Chevrolet', vehicle_model='Prizm', model_year=1999)
# Details(ssn=142873416, first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik', last_updated=datetime.datetime(2017, 5, 3, 14, 26, 58), created=datetime.datetime(2016, 12, 26, 21, 18, 54), employer='Altenwerth-Emard', department='Marketing', employee_id=305847411, vehicle_make='Ford', vehicle_model='Thunderbird', model_year=2005)
# Details(ssn=143174714, first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek', last_updated=datetime.datetime(2017, 7, 21, 18, 54, 47), created=datetime.datetime(2016, 2, 9, 6, 10, 21), employer='Cronin Inc', department='Business Development', employee_id=83106397, vehicle_make='Nissan', vehicle_model='Frontier', model_year=1999)
# Details(ssn=145108454, first_name='Donny', last_name='Laba', gender='Male', language='Japanese', last_updated=datetime.datetime(2017, 1, 18, 6, 37, 31), created=datetime.datetime(2016, 4, 25, 21, 45), employer='Murray, Wolff and Little', department='Business Development', employee_id=293578815, vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999)
# Details(ssn=145355124, first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi', last_updated=datetime.datetime(2018, 2, 20, 12, 47, 43), created=datetime.datetime(2016, 10, 3, 5, 18, 6), employer='Dibbert LLC', department='Support', employee_id=99620598, vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999)
# Details(ssn=145783985, first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian', last_updated=datetime.datetime(2017, 6, 10, 6, 21, 46), created=datetime.datetime(2016, 9, 23, 15, 35, 52), employer='Tromp Inc', department='Research and Development', employee_id=63360383, vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1993)
# Details(ssn=146813446, first_name='Korry', last_name='Billham', gender='Female', language='Hebrew', last_updated=datetime.datetime(2017, 1, 18, 8, 40, 14), created=datetime.datetime(2016, 9, 1, 8, 59, 50), employer='Kub, Koch and Ratke', department='Marketing', employee_id=727830449, vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1988)
# Details(ssn=147331463, first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento', last_updated=datetime.datetime(2018, 2, 9, 4, 41, 58), created=datetime.datetime(2016, 5, 31, 23, 38, 59), employer='Greenholt-Gusikowski', department='Engineering', employee_id=166006875, vehicle_make='GMC', vehicle_model='Vandura G1500', model_year=1995)
# Details(ssn=147478577, first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati', last_updated=datetime.datetime(2017, 4, 2, 18, 37, 59), created=datetime.datetime(2016, 12, 11, 3, 5, 36), employer='Tremblay, Jacobs and Swift', department='Training', employee_id=461648855, vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1996)
# Details(ssn=147633462, first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin', last_updated=datetime.datetime(2018, 2, 2, 13, 16, 51), created=datetime.datetime(2016, 7, 17, 4, 28, 52), employer='Bashirian-Moen', department='Training', employee_id=519115041, vehicle_make='Ford', vehicle_model='Explorer', model_year=2005)
# Details(ssn=148607519, first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer', last_updated=datetime.datetime(2017, 1, 22, 22, 15, 37), created=datetime.datetime(2016, 4, 29, 8, 42, 29), employer='Hudson-Gerhold', department='Human Resources', employee_id=622244500, vehicle_make='Mitsubishi', vehicle_model='RVR', model_year=1992)
# Details(ssn=149187272, first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento', last_updated=datetime.datetime(2017, 8, 31, 2, 41, 41), created=datetime.datetime(2016, 10, 21, 12, 17, 57), employer='Balistreri Inc', department='Sales', employee_id=928183627, vehicle_make='Mercedes-Benz', vehicle_model='500SEL', model_year=1992)
# Details(ssn=149456482, first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian', last_updated=datetime.datetime(2017, 9, 2, 5, 13, 32), created=datetime.datetime(2016, 2, 23, 16, 20, 59), employer='Eichmann, Quigley and Macejkovic', department='Business Development', employee_id=488059597, vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1995)
# Details(ssn=150646357, first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian', last_updated=datetime.datetime(2018, 2, 14, 23, 35, 53), created=datetime.datetime(2016, 1, 28, 3, 19, 50), employer='Bosco-Kunde', department='Services', employee_id=551726090, vehicle_make='Cadillac', vehicle_model='Escalade', model_year=2000)
# Details(ssn=150893343, first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha', last_updated=datetime.datetime(2017, 6, 4, 1, 39, 16), created=datetime.datetime(2016, 4, 23, 14, 7, 49), employer='Ratke-Raynor', department='Legal', employee_id=606687797, vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# Details(ssn=151543946, first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali', last_updated=datetime.datetime(2018, 2, 8, 11, 16, 12), created=datetime.datetime(2016, 10, 19, 8, 22, 59), employer='Bergstrom-Boyle', department='Marketing', employee_id=723121170, vehicle_make='Ford', vehicle_model='Probe', model_year=1996)
# Details(ssn=151700641, first_name='Urbain', last_name='Balint', gender='Male', language='Malagasy', last_updated=datetime.datetime(2017, 2, 13, 21, 31, 15), created=datetime.datetime(2016, 4, 28, 8, 28, 43), employer='McLaughlin-Rohan', department='Legal', employee_id=471922172, vehicle_make='Ford', vehicle_model='F250', model_year=1999)
# Details(ssn=151781397, first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho', last_updated=datetime.datetime(2017, 7, 8, 4, 22, 30), created=datetime.datetime(2016, 6, 11, 0, 28, 10), employer='Schinner, Swaniawski and Carter', department='Human Resources', employee_id=933103060, vehicle_make='BMW', vehicle_model='M5', model_year=2000)
# Details(ssn=152713526, first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish', last_updated=datetime.datetime(2018, 2, 25, 4, 17, 50), created=datetime.datetime(2016, 10, 8, 19, 49, 4), employer='Little, Hagenes and McKenzie', department='Training', employee_id=759906937, vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2001)
# Details(ssn=153671309, first_name='Annelise', last_name='Yushin', gender='Female', language='French', last_updated=datetime.datetime(2017, 8, 16, 12, 3, 37), created=datetime.datetime(2016, 12, 22, 19, 37, 39), employer='Gerlach, Bahringer and Rutherford', department='Accounting', employee_id=955604381, vehicle_make='Ford', vehicle_model='Taurus', model_year=1998)
# Details(ssn=154177912, first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi', last_updated=datetime.datetime(2017, 4, 19, 22, 8, 24), created=datetime.datetime(2016, 1, 29, 12, 43, 45), employer='Gorczany LLC', department='Training', employee_id=628983936, vehicle_make='Nissan', vehicle_model='Armada', model_year=2005)
# Details(ssn=156187547, first_name='Trey', last_name='Payne', gender='Male', language='West Frisian', last_updated=datetime.datetime(2017, 9, 10, 22, 58, 31), created=datetime.datetime(2016, 10, 20, 19, 49, 24), employer='Little, Powlowski and Witting', department='Business Development', employee_id=424459617, vehicle_make='Subaru', vehicle_model='Legacy', model_year=2011)
# Details(ssn=156916848, first_name='Carol', last_name='Cromar', gender='Female', language='Amharic', last_updated=datetime.datetime(2017, 8, 30, 22, 29, 10), created=datetime.datetime(2016, 5, 7, 6, 45, 32), employer='King LLC', department='Research and Development', employee_id=394026042, vehicle_make='Acura', vehicle_model='TL', model_year=2005)
# Details(ssn=157179982, first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish', last_updated=datetime.datetime(2017, 4, 17, 9, 11, 49), created=datetime.datetime(2016, 3, 17, 0, 22, 29), employer='Konopelski-Vandervort', department='Legal', employee_id=878332368, vehicle_make='Audi', vehicle_model='Q7', model_year=2007)
# Details(ssn=157387090, first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans', last_updated=datetime.datetime(2017, 3, 24, 8, 58, 33), created=datetime.datetime(2016, 9, 15, 16, 11, 12), employer='Reichel Group', department='Training', employee_id=105605387, vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=2005)
# Details(ssn=157515269, first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi', last_updated=datetime.datetime(2017, 11, 4, 20, 16, 50), created=datetime.datetime(2016, 6, 17, 10, 3, 2), employer='Gerhold-Marquardt', department='Research and Development', employee_id=256013938, vehicle_make='BMW', vehicle_model='Z3', model_year=1996)
# Details(ssn=161369710, first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish', last_updated=datetime.datetime(2017, 7, 3, 6, 26, 41), created=datetime.datetime(2016, 6, 9, 5, 30, 33), employer='Greenholt-Hermiston', department='Business Development', employee_id=669841280, vehicle_make='Mercedes-Benz', vehicle_model='SLK-Class', model_year=1999)
# Details(ssn=161534778, first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz', last_updated=datetime.datetime(2017, 12, 3, 11, 9, 18), created=datetime.datetime(2016, 12, 9, 18, 37, 55), employer='Oberbrunner, Donnelly and Gibson', department='Human Resources', employee_id=832548521, vehicle_make='Ford', vehicle_model='Mustang', model_year=1995)
# Details(ssn=163688070, first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino', last_updated=datetime.datetime(2017, 9, 6, 16, 56, 6), created=datetime.datetime(2016, 10, 23, 1, 47, 51), employer='Roberts Group', department='Product Management', employee_id=76620387, vehicle_make='Lincoln', vehicle_model='Continental', model_year=1998)
# Details(ssn=163981022, first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian', last_updated=datetime.datetime(2017, 3, 26, 4, 2, 28), created=datetime.datetime(2016, 3, 22, 11, 24, 33), employer='Olson-Lynch', department='Business Development', employee_id=507113609, vehicle_make='Honda', vehicle_model='Civic', model_year=2012)
# Details(ssn=164119849, first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian', last_updated=datetime.datetime(2017, 6, 24, 10, 17, 58), created=datetime.datetime(2016, 4, 20, 11, 9, 5), employer='Quitzon, Rempel and Hane', department='Business Development', employee_id=34767523, vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2001)
# Details(ssn=166104488, first_name='Lester', last_name='Keyson', gender='Male', language='Bislama', last_updated=datetime.datetime(2017, 8, 14, 16, 48, 43), created=datetime.datetime(2016, 7, 2, 8, 33, 48), employer='Carroll, Konopelski and Wunsch', department='Research and Development', employee_id=434797129, vehicle_make='Cadillac', vehicle_model='DTS', model_year=2008)
# Details(ssn=167392377, first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese', last_updated=datetime.datetime(2017, 10, 31, 22, 27, 7), created=datetime.datetime(2016, 2, 3, 10, 32, 1), employer='Howell LLC', department='Business Development', employee_id=702399476, vehicle_make='GMC', vehicle_model='3500', model_year=1998)
# Details(ssn=168025324, first_name='Dane', last_name='Cornick', gender='Male', language='Tajik', last_updated=datetime.datetime(2018, 1, 4, 21, 50, 39), created=datetime.datetime(2016, 1, 29, 15, 31, 40), employer='Johnson Inc', department='Services', employee_id=347741883, vehicle_make='Volkswagen', vehicle_model='Fox', model_year=1989)
# Details(ssn=168198754, first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian', last_updated=datetime.datetime(2017, 6, 10, 3, 48, 51), created=datetime.datetime(2016, 9, 27, 15, 4, 24), employer='Corwin and Sons', department='Legal', employee_id=158160997, vehicle_make='Toyota', vehicle_model='MR2', model_year=1993)
# Details(ssn=168810838, first_name='Toby', last_name='Pond-Jones', gender='Female', language='Aymara', last_updated=datetime.datetime(2017, 2, 11, 14, 12, 16), created=datetime.datetime(2016, 9, 19, 20, 5, 7), employer='Zemlak LLC', department='Research and Development', employee_id=868667896, vehicle_make='Mazda', vehicle_model='Mazda5', model_year=2012)
# Details(ssn=168896661, first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum', last_updated=datetime.datetime(2017, 7, 17, 2, 59, 15), created=datetime.datetime(2016, 4, 30, 9, 17, 39), employer='Toy-Jakubowski', department='Engineering', employee_id=178085199, vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1964)
# Details(ssn=170653388, first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese', last_updated=datetime.datetime(2017, 3, 5, 0, 46, 26), created=datetime.datetime(2016, 6, 15, 5, 37, 27), employer='Murphy, Windler and Bartoletti', department='Legal', employee_id=26976472, vehicle_make='Dodge', vehicle_model='Caravan', model_year=2010)
# Details(ssn=171277781, first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao', last_updated=datetime.datetime(2017, 3, 5, 9, 35, 8), created=datetime.datetime(2016, 9, 23, 3, 10, 37), employer='Batz Inc', department='Support', employee_id=492738721, vehicle_make='Ford', vehicle_model='Mustang', model_year=1985)
# Details(ssn=172237739, first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz', last_updated=datetime.datetime(2018, 3, 2, 23, 30, 36), created=datetime.datetime(2016, 5, 12, 16, 1, 48), employer='Jast and Sons', department='Services', employee_id=386141294, vehicle_make='Mazda', vehicle_model='Mazdaspeed 3', model_year=2011)
# Details(ssn=172774263, first_name='Alex', last_name='Udie', gender='Male', language='French', last_updated=datetime.datetime(2017, 10, 11, 13, 32, 41), created=datetime.datetime(2016, 9, 10, 9, 18, 50), employer='Roberts LLC', department='Research and Development', employee_id=912028080, vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# Details(ssn=172897546, first_name='Trude', last_name='Gillson', gender='Female', language='Norwegian', last_updated=datetime.datetime(2017, 1, 25, 2, 11, 6), created=datetime.datetime(2016, 7, 24, 12, 57, 57), employer='Schultz, Price and Walsh', department='Business Development', employee_id=696328477, vehicle_make='Mercury', vehicle_model='Cougar', model_year=1969)
# Details(ssn=173997372, first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish', last_updated=datetime.datetime(2018, 3, 3, 15, 18, 26), created=datetime.datetime(2016, 10, 26, 15, 24, 37), employer='Zulauf, Hudson and Wisozk', department='Research and Development', employee_id=391896194, vehicle_make='Kia', vehicle_model='Sephia', model_year=1997)
# Details(ssn=174132047, first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu', last_updated=datetime.datetime(2017, 1, 28, 14, 24, 40), created=datetime.datetime(2016, 1, 12, 16, 53, 59), employer='Bode-Zulauf', department='Marketing', employee_id=420021775, vehicle_make='Mitsubishi', vehicle_model='L300', model_year=1988)
# Details(ssn=174353812, first_name='Sayer', last_name='Astling', gender='Male', language='Kyrgyz', last_updated=datetime.datetime(2017, 1, 25, 11, 34, 25), created=datetime.datetime(2016, 5, 14, 4, 55, 35), employer='Windler Group', department='Legal', employee_id=162190623, vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1972)
# Details(ssn=174519992, first_name='Drucie', last_name='Travers', gender='Female', language='Swati', last_updated=datetime.datetime(2017, 3, 3, 19, 42, 18), created=datetime.datetime(2016, 5, 17, 23, 32, 25), employer='Jast-Quitzon', department='Human Resources', employee_id=675707294, vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1994)
# Details(ssn=174872537, first_name='Benton', last_name='Nolte', gender='Male', language='Persian', last_updated=datetime.datetime(2017, 9, 30, 14, 38, 36), created=datetime.datetime(2016, 8, 1, 11, 19, 25), employer='Green-Waelchi', department='Engineering', employee_id=297065788, vehicle_make='Ford', vehicle_model='Taurus', model_year=1991)
# Details(ssn=176821359, first_name='Corny', last_name='Rothera', gender='Female', language='Thai', last_updated=datetime.datetime(2017, 1, 14, 13, 36, 1), created=datetime.datetime(2016, 11, 29, 19, 3, 42), employer='Brown Group', department='Accounting', employee_id=910435820, vehicle_make='Toyota', vehicle_model='Celica', model_year=1995)
# Details(ssn=176995851, first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan', last_updated=datetime.datetime(2017, 4, 1, 20, 14, 53), created=datetime.datetime(2016, 12, 3, 15, 8, 4), employer='MacGyver-Hartmann', department='Accounting', employee_id=774207310, vehicle_make='Jeep', vehicle_model='Commander', model_year=2007)
# Details(ssn=179882790, first_name='Errick', last_name='Charsley', gender='Male', language='Japanese', last_updated=datetime.datetime(2017, 3, 23, 1, 30, 12), created=datetime.datetime(2016, 3, 6, 13, 15, 20), employer='McGlynn LLC', department='Support', employee_id=354393230, vehicle_make='Chevrolet', vehicle_model='Malibu', model_year=2013)
# Details(ssn=181074434, first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan', last_updated=datetime.datetime(2017, 10, 7, 7, 52, 10), created=datetime.datetime(2016, 11, 11, 20, 19, 19), employer='Little, Herzog and Mertz', department='Legal', employee_id=459164509, vehicle_make='Chevrolet', vehicle_model='Impala SS', model_year=1995)
# Details(ssn=181288337, first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan', last_updated=datetime.datetime(2017, 11, 30, 23, 28), created=datetime.datetime(2016, 4, 27, 20, 53, 49), employer='Kertzmann-Reichel', department='Research and Development', employee_id=670581933, vehicle_make='GMC', vehicle_model='Canyon', model_year=2004)
# Details(ssn=181886077, first_name='Ebba', last_name='Wozencroft', gender='Female', language='German', last_updated=datetime.datetime(2017, 8, 16, 21, 35, 50), created=datetime.datetime(2016, 9, 15, 10, 22, 56), employer='Douglas, Funk and Schowalter', department='Services', employee_id=772512148, vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2008)
# Details(ssn=182155082, first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili', last_updated=datetime.datetime(2017, 10, 2, 6, 22, 27), created=datetime.datetime(2016, 10, 16, 12, 16, 53), employer='Bayer-Kunze', department='Support', employee_id=866996270, vehicle_make='Mercedes-Benz', vehicle_model='S-Class', model_year=1988)
# Details(ssn=182814541, first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish', last_updated=datetime.datetime(2017, 7, 5, 10, 19, 41), created=datetime.datetime(2016, 7, 23, 3, 16, 13), employer='Kiehn, Hansen and Will', department='Support', employee_id=948005696, vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=1997)
# Details(ssn=183105024, first_name='Curran', last_name='Squires', gender='Male', language='Romanian', last_updated=datetime.datetime(2017, 11, 3, 0, 36, 20), created=datetime.datetime(2016, 9, 8, 5, 10, 46), employer='Kling-Howe', department='Research and Development', employee_id=717470887, vehicle_make='Maserati', vehicle_model='Spyder', model_year=1991)
# Details(ssn=184606243, first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin', last_updated=datetime.datetime(2018, 2, 26, 15, 42, 50), created=datetime.datetime(2016, 6, 16, 15, 17, 46), employer='Quitzon-Morissette', department='Product Management', employee_id=815434446, vehicle_make='Ford', vehicle_model='Mustang', model_year=1998)
# Details(ssn=184841003, first_name='Bary', last_name='Buzin', gender='Male', language='Aymara', last_updated=datetime.datetime(2017, 10, 15, 21, 11, 17), created=datetime.datetime(2016, 11, 17, 18, 52, 56), employer='Bergstrom-Daniel', department='Marketing', employee_id=317381298, vehicle_make='Mercury', vehicle_model='Mystique', model_year=1997)
# Details(ssn=184923560, first_name='Kore', last_name='Eastes', gender='Female', language='Fijian', last_updated=datetime.datetime(2017, 2, 16, 4, 37, 8), created=datetime.datetime(2016, 7, 26, 19, 25, 30), employer='Johnston, Leuschke and Stracke', department='Support', employee_id=969321837, vehicle_make='Scion', vehicle_model='xD', model_year=2011)
# Details(ssn=184945241, first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati', last_updated=datetime.datetime(2017, 3, 28, 16, 56, 35), created=datetime.datetime(2016, 6, 3, 5, 38, 20), employer='Lubowitz-Franecki', department='Product Management', employee_id=685287750, vehicle_make='Audi', vehicle_model='90', model_year=1991)
# Details(ssn=185500434, first_name='Alexa', last_name='Emblin', gender='Female', language='Quechua', last_updated=datetime.datetime(2017, 2, 19, 15, 12, 50), created=datetime.datetime(2016, 10, 24, 14, 3, 4), employer='Nienow-Metz', department='Legal', employee_id=885601438, vehicle_make='Suzuki', vehicle_model='X-90', model_year=1998)
# Details(ssn=185849868, first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho', last_updated=datetime.datetime(2017, 7, 1, 13, 56, 28), created=datetime.datetime(2016, 8, 8, 8, 4, 45), employer='Quitzon, Stiedemann and Breitenberg', department='Services', employee_id=761399493, vehicle_make='Mercury', vehicle_model='Sable', model_year=2001)
# Details(ssn=186657773, first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi', last_updated=datetime.datetime(2017, 6, 9, 12, 34, 32), created=datetime.datetime(2016, 9, 17, 22, 55, 15), employer='Turner-Connelly', department='Research and Development', employee_id=921687621, vehicle_make='Mitsubishi', vehicle_model='Precis', model_year=1990)
# Details(ssn=188209317, first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai', last_updated=datetime.datetime(2017, 12, 26, 5, 29, 23), created=datetime.datetime(2016, 6, 5, 4, 26, 52), employer='Kling, Prosacco and Wisoky', department='Accounting', employee_id=770491080, vehicle_make='Chevrolet', vehicle_model='Avalanche 2500', model_year=2003)
# Details(ssn=188404336, first_name='Belita', last_name='Camolli', gender='Female', language='Telugu', last_updated=datetime.datetime(2017, 12, 27, 3, 41, 46), created=datetime.datetime(2016, 6, 30, 2, 48, 10), employer="Von, O'Kon and Runolfsdottir", department='Research and Development', employee_id=346414700, vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1985)
# Details(ssn=189265696, first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin', last_updated=datetime.datetime(2017, 8, 8, 19, 29, 59), created=datetime.datetime(2016, 9, 9, 19, 38, 18), employer='McLaughlin-Botsford', department='Business Development', employee_id=602450272, vehicle_make='BMW', vehicle_model='8 Series', model_year=1995)
# Details(ssn=189491458, first_name='Vernen', last_name='Ivanyushkin', gender='Male', language='Quechua', last_updated=datetime.datetime(2017, 2, 12, 16, 15, 44), created=datetime.datetime(2016, 6, 21, 4, 10, 57), employer='Mann-Stehr', department='Sales', employee_id=829383132, vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008)
# Details(ssn=190056987, first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian', last_updated=datetime.datetime(2017, 6, 6, 20, 51, 23), created=datetime.datetime(2016, 2, 17, 12, 0, 16), employer='Smitham-Blick', department='Engineering', employee_id=73918459, vehicle_make='Subaru', vehicle_model='Legacy', model_year=1990)
# Details(ssn=190534517, first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili', last_updated=datetime.datetime(2018, 2, 12, 20, 26, 30), created=datetime.datetime(2016, 4, 15, 16, 42, 18), employer='Reilly and Sons', department='Product Management', employee_id=2155545, vehicle_make='Hyundai', vehicle_model='Sonata', model_year=1993)
# Details(ssn=191153194, first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai', last_updated=datetime.datetime(2017, 7, 27, 9, 14, 42), created=datetime.datetime(2016, 5, 23, 13, 52, 39), employer='Keeling, Hansen and Mertz', department='Training', employee_id=863420084, vehicle_make='Mercury', vehicle_model='Grand Marquis', model_year=2009)
# Details(ssn=192540695, first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori', last_updated=datetime.datetime(2017, 3, 18, 6, 5, 59), created=datetime.datetime(2016, 11, 16, 1, 58, 55), employer='Mante Inc', department='Business Development', employee_id=398018810, vehicle_make='Volvo', vehicle_model='C70', model_year=1998)
# Details(ssn=192673201, first_name='Edvard', last_name='Cattel', gender='Male', language='Hebrew', last_updated=datetime.datetime(2017, 1, 19, 20, 59, 49), created=datetime.datetime(2016, 6, 13, 1, 23, 53), employer='Nicolas Group', department='Support', employee_id=752636577, vehicle_make='Mitsubishi', vehicle_model='Galant', model_year=1999)
# Details(ssn=194765816, first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic', last_updated=datetime.datetime(2017, 1, 16, 18, 22, 53), created=datetime.datetime(2016, 5, 26, 16, 11, 14), employer='Sauer, Mann and Kling', department='Accounting', employee_id=893029716, vehicle_make='Dodge', vehicle_model='Dakota', model_year=2001)
# Details(ssn=195235731, first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese', last_updated=datetime.datetime(2017, 5, 22, 16, 24, 23), created=datetime.datetime(2016, 10, 23, 11, 15, 3), employer='Hodkiewicz, Rau and Ryan', department='Marketing', employee_id=292776451, vehicle_make='Saturn', vehicle_model='Outlook', model_year=2007)
# Details(ssn=196693796, first_name='Marijo', last_name='Tester', gender='Female', language='Oriya', last_updated=datetime.datetime(2017, 1, 23, 2, 41, 20), created=datetime.datetime(2016, 8, 1, 21, 34, 6), employer='Prosacco LLC', department='Business Development', employee_id=536059808, vehicle_make='Subaru', vehicle_model='Legacy', model_year=2007)
# Details(ssn=198706443, first_name='Judah', last_name='Duggan', gender='Male', language='Macedonian', last_updated=datetime.datetime(2017, 2, 13, 7, 16, 31), created=datetime.datetime(2016, 1, 22, 5, 10, 14), employer='Mante, Roberts and Miller', department='Research and Development', employee_id=981318396, vehicle_make='Infiniti', vehicle_model='QX', model_year=2005)
# Details(ssn=199450804, first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana', last_updated=datetime.datetime(2017, 6, 23, 12, 59, 20), created=datetime.datetime(2016, 11, 7, 0, 25, 12), employer='Farrell and Sons', department='Product Management', employee_id=853648779, vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2003)
# Details(ssn=199544639, first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali', last_updated=datetime.datetime(2018, 2, 23, 10, 14, 54), created=datetime.datetime(2016, 4, 5, 5, 11, 13), employer='Heathcote-Torp', department='Product Management', employee_id=772681193, vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2006)
# Details(ssn=200817151, first_name='Merilyn', last_name='Tink', gender='Female', language='Bengali', last_updated=datetime.datetime(2017, 11, 19, 13, 58, 42), created=datetime.datetime(2016, 7, 31, 19, 2, 12), employer='Hilpert, Kassulke and Gutkowski', department='Research and Development', employee_id=26484055, vehicle_make='Mitsubishi', vehicle_model='Tredia', model_year=1985)
# ...
# Details(ssn=860670256, first_name='Bendicty', last_name='Lindgren', gender='Male', language='Tajik', last_updated=datetime.datetime(2017, 1, 9, 22, 49, 48), created=datetime.datetime(2016, 2, 6, 4, 59, 26), employer='Williamson-Lemke', department='Accounting', employee_id=809563373, vehicle_make='Toyota', vehicle_model='Tacoma', model_year=2001)
# Details(ssn=860892570, first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish', last_updated=datetime.datetime(2017, 4, 15, 11, 12, 57), created=datetime.datetime(2016, 6, 22, 23, 23, 9), employer='Reinger Inc', department='Engineering', employee_id=802005731, vehicle_make='Dodge', vehicle_model='Dakota', model_year=2007)
# Details(ssn=861506716, first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian', last_updated=datetime.datetime(2018, 3, 30, 21, 7, 8), created=datetime.datetime(2016, 9, 16, 9, 12, 34), employer='Stokes Inc', department='Training', employee_id=126635955, vehicle_make='BMW', vehicle_model='M5', model_year=2007)
# Details(ssn=862200653, first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish', last_updated=datetime.datetime(2017, 5, 3, 14, 37, 42), created=datetime.datetime(2016, 2, 4, 14, 11, 40), employer='Dicki, Green and White', department='Services', employee_id=871017676, vehicle_make='Mazda', vehicle_model='B-Series', model_year=2002)
# Details(ssn=864229364, first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian', last_updated=datetime.datetime(2017, 2, 4, 13, 53, 10), created=datetime.datetime(2016, 12, 28, 0, 33, 8), employer='Thiel, Parker and Hilpert', department='Marketing', employee_id=202324966, vehicle_make='Acura', vehicle_model='ZDX', model_year=2011)
# Details(ssn=864917489, first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama', last_updated=datetime.datetime(2017, 2, 3, 17, 51, 18), created=datetime.datetime(2016, 2, 14, 3, 7, 23), employer='Heidenreich, Stehr and Huel', department='Sales', employee_id=891713880, vehicle_make='Pontiac', vehicle_model='Grand Am', model_year=2004)
# Details(ssn=866181440, first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento', last_updated=datetime.datetime(2017, 5, 31, 4, 28, 19), created=datetime.datetime(2016, 2, 2, 17, 47, 22), employer='Bartoletti Inc', department='Support', employee_id=777239839, vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# Details(ssn=866530625, first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian', last_updated=datetime.datetime(2018, 2, 24, 20, 22, 43), created=datetime.datetime(2016, 12, 15, 22, 59, 20), employer='Douglas-Breitenberg', department='Business Development', employee_id=636285198, vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1997)
# Details(ssn=867116007, first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam', last_updated=datetime.datetime(2018, 1, 25, 4, 2, 4), created=datetime.datetime(2016, 10, 31, 14, 12, 16), employer='Nitzsche-Walker', department='Engineering', employee_id=505681388, vehicle_make='Volvo', vehicle_model='S80', model_year=2001)
# Details(ssn=867136844, first_name='Clo', last_name='Skacel', gender='Female', language='Armenian', last_updated=datetime.datetime(2017, 10, 31, 17, 48, 23), created=datetime.datetime(2016, 7, 17, 9, 50, 7), employer='Crist, Leuschke and Grimes', department='Legal', employee_id=98398802, vehicle_make='Land Rover', vehicle_model='Range Rover', model_year=1986)
# Details(ssn=867882360, first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha', last_updated=datetime.datetime(2018, 3, 11, 16, 42, 31), created=datetime.datetime(2016, 11, 4, 18, 34, 52), employer='Emard Inc', department='Business Development', employee_id=492589434, vehicle_make='Ford', vehicle_model='F-Series', model_year=1987)
# Details(ssn=868321805, first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian', last_updated=datetime.datetime(2017, 9, 29, 17, 46, 17), created=datetime.datetime(2016, 11, 14, 1, 26, 32), employer='Abshire Inc', department='Research and Development', employee_id=558987515, vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2007)
# Details(ssn=870126609, first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana', last_updated=datetime.datetime(2017, 1, 19, 3, 43, 35), created=datetime.datetime(2016, 6, 24, 16, 43, 15), employer='Thompson, Parker and Moen', department='Research and Development', employee_id=461484106, vehicle_make='Mercedes-Benz', vehicle_model='W201', model_year=1991)
# Details(ssn=870931121, first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew', last_updated=datetime.datetime(2017, 3, 3, 3, 45, 30), created=datetime.datetime(2016, 6, 21, 17, 1, 53), employer='Morissette, Rowe and Muller', department='Engineering', employee_id=739912953, vehicle_make='Mitsubishi', vehicle_model='Pajero', model_year=1998)
# Details(ssn=871993191, first_name='Susann', last_name='Walrond', gender='Female', language='Amharic', last_updated=datetime.datetime(2017, 5, 8, 8, 24, 12), created=datetime.datetime(2016, 2, 27, 15, 43, 26), employer='Lueilwitz, Stokes and Kassulke', department='Marketing', employee_id=161937114, vehicle_make='Toyota', vehicle_model='Sienna', model_year=2000)
# Details(ssn=872189267, first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese', last_updated=datetime.datetime(2018, 3, 22, 21, 11, 58), created=datetime.datetime(2016, 4, 27, 3, 27, 17), employer='Glover, Jacobs and Heidenreich', department='Sales', employee_id=721577952, vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# Details(ssn=872491288, first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish', last_updated=datetime.datetime(2017, 12, 6, 2, 19, 8), created=datetime.datetime(2016, 6, 10, 10, 5, 19), employer='Cummings-Mertz', department='Sales', employee_id=782291834, vehicle_make='Acura', vehicle_model='Integra', model_year=1997)
# Details(ssn=873364733, first_name='Locke', last_name='Staries', gender='Male', language='Moldovan', last_updated=datetime.datetime(2017, 7, 23, 1, 30, 5), created=datetime.datetime(2016, 7, 8, 7, 10, 52), employer='Wilderman-Grimes', department='Engineering', employee_id=396055619, vehicle_make='Austin', vehicle_model='Mini Cooper', model_year=1964)
# Details(ssn=875189454, first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu', last_updated=datetime.datetime(2017, 3, 14, 4, 45, 19), created=datetime.datetime(2016, 8, 19, 18, 23, 57), employer='Schultz-Medhurst', department='Support', employee_id=566050344, vehicle_make='Mitsubishi', vehicle_model='Diamante', model_year=1993)
# Details(ssn=875750495, first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish', last_updated=datetime.datetime(2017, 12, 3, 21, 27, 47), created=datetime.datetime(2016, 6, 12, 12, 36, 44), employer='Wunsch-Gleason', department='Services', employee_id=283015726, vehicle_make='Hyundai', vehicle_model='Tiburon', model_year=2000)
# Details(ssn=878128265, first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi', last_updated=datetime.datetime(2017, 1, 11, 18, 36, 16), created=datetime.datetime(2016, 3, 14, 14, 30, 37), employer='Witting, Schuster and Barton', department='Research and Development', employee_id=544161357, vehicle_make='Chrysler', vehicle_model='Concorde', model_year=1998)
# Details(ssn=880224449, first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri', last_updated=datetime.datetime(2017, 1, 13, 19, 50, 26), created=datetime.datetime(2016, 6, 11, 20, 35, 38), employer='Harber-Legros', department='Training', employee_id=599280036, vehicle_make='Toyota', vehicle_model='Camry', model_year=2008)
# Details(ssn=881195974, first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho', last_updated=datetime.datetime(2018, 2, 4, 17, 29, 28), created=datetime.datetime(2016, 10, 5, 21, 57, 12), employer='Daugherty, Gislason and Kreiger', department='Training', employee_id=255973403, vehicle_make='Infiniti', vehicle_model='G', model_year=2004)
# Details(ssn=881887308, first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga', last_updated=datetime.datetime(2017, 8, 11, 11, 40, 28), created=datetime.datetime(2016, 1, 18, 12, 51), employer="O'Connell, Raynor and Veum", department='Sales', employee_id=160843654, vehicle_make='Subaru', vehicle_model='SVX', model_year=1994)
# Details(ssn=881957180, first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian', last_updated=datetime.datetime(2018, 1, 29, 16, 6, 26), created=datetime.datetime(2016, 11, 24, 12, 12, 51), employer='Schumm Inc', department='Services', employee_id=188360445, vehicle_make='BMW', vehicle_model='M6', model_year=2009)
# Details(ssn=882495290, first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian', last_updated=datetime.datetime(2017, 2, 10, 19, 26, 8), created=datetime.datetime(2016, 8, 27, 5, 43, 5), employer='Zulauf Inc', department='Accounting', employee_id=467067366, vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011)
# Details(ssn=884611852, first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian', last_updated=datetime.datetime(2017, 1, 9, 19, 30, 49), created=datetime.datetime(2016, 3, 18, 22, 13, 6), employer='Stanton, Price and Wehner', department='Services', employee_id=165769119, vehicle_make='Plymouth', vehicle_model='Neon', model_year=1996)
# Details(ssn=887417878, first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil', last_updated=datetime.datetime(2017, 3, 27, 13, 38, 47), created=datetime.datetime(2016, 9, 14, 9, 26, 53), employer='Ziemann, Denesik and Casper', department='Research and Development', employee_id=716097002, vehicle_make='Lexus', vehicle_model='GS', model_year=2013)
# Details(ssn=887839002, first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin', last_updated=datetime.datetime(2017, 12, 19, 6, 24, 25), created=datetime.datetime(2016, 5, 30, 2, 40, 28), employer='Terry and Sons', department='Research and Development', employee_id=69390159, vehicle_make='Audi', vehicle_model='S6', model_year=2011)
# Details(ssn=888507008, first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha', last_updated=datetime.datetime(2018, 3, 6, 16, 54, 20), created=datetime.datetime(2016, 6, 9, 11, 3, 40), employer='Herzog, Stehr and Quitzon', department='Engineering', employee_id=385385705, vehicle_make='Nissan', vehicle_model='Armada', model_year=2008)
# Details(ssn=888537684, first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian', last_updated=datetime.datetime(2017, 9, 5, 0, 30), created=datetime.datetime(2016, 2, 12, 1, 35, 59), employer='Collier, Hilll and Hagenes', department='Training', employee_id=156651242, vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=1991)
# Details(ssn=888824928, first_name='Billye', last_name='Legat', gender='Female', language='Icelandic', last_updated=datetime.datetime(2017, 12, 8, 14, 2, 48), created=datetime.datetime(2016, 11, 9, 10, 4, 16), employer='Reynolds, Nicolas and Morar', department='Engineering', employee_id=483998718, vehicle_make='Volvo', vehicle_model='S60', model_year=2005)
# Details(ssn=890289962, first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua', last_updated=datetime.datetime(2018, 1, 6, 9, 34, 59), created=datetime.datetime(2016, 2, 22, 15, 24, 59), employer='Heller, Kihn and Bartoletti', department='Research and Development', employee_id=569393666, vehicle_make='GMC', vehicle_model='Savana 1500', model_year=2000)
# Details(ssn=893120901, first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya', last_updated=datetime.datetime(2018, 3, 27, 1, 24, 58), created=datetime.datetime(2016, 6, 14, 2, 41, 25), employer='Christiansen LLC', department='Sales', employee_id=661175841, vehicle_make='Lotus', vehicle_model='Esprit', model_year=1991)
# Details(ssn=893177318, first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz', last_updated=datetime.datetime(2017, 7, 23, 7, 11, 51), created=datetime.datetime(2016, 2, 28, 8, 1, 12), employer='Orn Inc', department='Human Resources', employee_id=384356300, vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=1995)
# Details(ssn=894810628, first_name='Ree', last_name='Mordue', gender='Female', language='Tswana', last_updated=datetime.datetime(2017, 3, 7, 4, 8, 28), created=datetime.datetime(2016, 7, 9, 11, 43, 17), employer='Flatley, Senger and Bernier', department='Services', employee_id=722633200, vehicle_make='Kia', vehicle_model='Sedona', model_year=2012)
# Details(ssn=895261658, first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic', last_updated=datetime.datetime(2017, 4, 1, 22, 22, 5), created=datetime.datetime(2016, 11, 22, 6, 57, 45), employer='Hilll, Kunze and Beer', department='Human Resources', employee_id=904168298, vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=2003)
# Details(ssn=895265515, first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho', last_updated=datetime.datetime(2017, 5, 13, 5, 52, 27), created=datetime.datetime(2016, 3, 24, 7, 34, 14), employer='Franecki LLC', department='Services', employee_id=637802530, vehicle_make='Acura', vehicle_model='TL', model_year=1999)
# Details(ssn=897767070, first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali', last_updated=datetime.datetime(2017, 11, 27, 19, 4, 22), created=datetime.datetime(2016, 12, 12, 7, 39, 48), employer='Reilly-Jakubowski', department='Marketing', employee_id=776363112, vehicle_make='BMW', vehicle_model='X3', model_year=2011)
# Details(ssn=898033165, first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic', last_updated=datetime.datetime(2017, 6, 1, 19, 18, 49), created=datetime.datetime(2016, 7, 20, 21, 40, 2), employer='Bins-Gerhold', department='Sales', employee_id=899965641, vehicle_make='Toyota', vehicle_model='Xtra', model_year=1994)
# Details(ssn=898868860, first_name='Hershel', last_name='Few', gender='Male', language='Gagauz', last_updated=datetime.datetime(2017, 7, 3, 14, 27, 26), created=datetime.datetime(2016, 11, 23, 23, 34, 17), employer='Olson-Johnson', department='Support', employee_id=367761827, vehicle_make='Lotus', vehicle_model='Esprit', model_year=2003)
# Details(ssn=899091766, first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino', last_updated=datetime.datetime(2017, 7, 31, 2, 26, 57), created=datetime.datetime(2016, 10, 27, 18, 41, 56), employer='Cronin LLC', department='Services', employee_id=838730953, vehicle_make='Toyota', vehicle_model='Camry', model_year=2012)
# Details(ssn=899397179, first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek', last_updated=datetime.datetime(2017, 8, 2, 13, 32, 33), created=datetime.datetime(2016, 7, 27, 12, 47, 5), employer='Little-Hansen', department='Business Development', employee_id=458154226, vehicle_make='Infiniti', vehicle_model='FX', model_year=2006)
# Details(ssn=899397378, first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian', last_updated=datetime.datetime(2017, 3, 27, 19, 31, 32), created=datetime.datetime(2016, 9, 4, 15, 9, 22), employer="Christiansen, Ondricka and O'Connell", department='Marketing', employee_id=327034344, vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=1999)
# Details(ssn=899476116, first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum', last_updated=datetime.datetime(2017, 6, 10, 11, 20, 41), created=datetime.datetime(2016, 4, 29, 12, 25, 23), employer='Bednar LLC', department='Support', employee_id=166342889, vehicle_make='Volkswagen', vehicle_model='Phaeton', model_year=2005)

# %% [markdown]
# # SSNLatestDetails Iterable with latest entries updated after 1st March 2017, aggregates the named tuples into single one

# %%
class SSNLatestDetails:
    def __init__(self,personal_info_file,update_status_file,emp_status_file,vehicles_file):
        self.personal_info_file = personal_info_file
        self.update_status_file = update_status_file
        self.emp_status_file = emp_status_file
        self.vehicles_file = vehicles_file
    
    def __iter__(self):
        return self.SSNIterator(self.personal_info_file,self.update_status_file,self.emp_status_file,
                                self.vehicles_file)
    
    class SSNIterator:
        def __init__(self,personal_info_file,update_status_file,emp_status_file,vehicles_file):
            self.personal_info_iterator = personal_info_iterator(personal_info_file)
            self.update_status_iterator = update_status_iterator(update_status_file)
            self.emp_status_iterator = emp_status_iterator(emp_status_file)
            self.vehicles_iterator = vehicles_iterator(vehicles_file)
            
        def __iter__(self):
            return self
        
        def merge(self,ntuples):
            m = {}
            for i in ntuples:
                m.update(i._asdict())
            M = namedtuple("M", m.keys())(*m.values())
            return M
        
        def __next__(self):
            while True:
                personal_info_tuple = next(self.personal_info_iterator)
                update_status_tuple = next(self.update_status_iterator)
                emp_status_tuple = next(self.emp_status_iterator)
                vehicles_tuple = next(self.vehicles_iterator)
                if getattr(update_status_tuple, 'last_updated') >= datetime(2017, 3, 1, 0, 0, 0):
                    break
            return self.merge([personal_info_tuple, update_status_tuple, emp_status_tuple, vehicles_tuple])

# %%
itr = SSNLatestDetails('personal_info.csv','update_status.csv','employment.csv','vehicles.csv' )

# %%
for entry in itr:
    print(entry)
# Out:
# M(ssn=100539824, first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic', last_updated=datetime.datetime(2017, 10, 7, 0, 14, 42), created=datetime.datetime(2016, 1, 24, 21, 19, 30), employer='Stiedemann-Bailey', department='Research and Development', employee_id=290890771, vehicle_make='Oldsmobile', vehicle_model='Bravada', model_year=1993)
# M(ssn=101840356, first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish', last_updated=datetime.datetime(2017, 10, 4, 11, 21, 30), created=datetime.datetime(2016, 9, 21, 23, 4, 7), employer='Connelly Group', department='Research and Development', employee_id=987952860, vehicle_make='GMC', vehicle_model='Yukon', model_year=2005)
# M(ssn=104220928, first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi', last_updated=datetime.datetime(2017, 3, 28, 12, 38, 29), created=datetime.datetime(2016, 4, 15, 11, 37, 17), employer='Upton LLC', department='Marketing', employee_id=569817552, vehicle_make='Oldsmobile', vehicle_model='Intrigue', model_year=2000)
# M(ssn=104847144, first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans', last_updated=datetime.datetime(2018, 2, 19, 1, 34, 33), created=datetime.datetime(2016, 3, 15, 14, 7, 57), employer='Zemlak-Olson', department='Business Development', employee_id=462886707, vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=2008)
# M(ssn=105275541, first_name='Federico', last_name='Aggett', gender='Male', language='Chinese', last_updated=datetime.datetime(2017, 7, 24, 8, 58, 52), created=datetime.datetime(2016, 7, 23, 17, 58, 35), employer='Kohler, Bradtke and Davis', department='Support', employee_id=800975518, vehicle_make='Ford', vehicle_model='Mustang', model_year=2001)
# M(ssn=105857486, first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi', last_updated=datetime.datetime(2018, 2, 14, 11, 32, 39), created=datetime.datetime(2016, 12, 15, 5, 46, 43), employer='Roberts, Torphy and Dach', department='Human Resources', employee_id=774895332, vehicle_make='Chrysler', vehicle_model='300', model_year=2008)
# M(ssn=105915022, first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian', last_updated=datetime.datetime(2018, 3, 24, 14, 29, 33), created=datetime.datetime(2016, 3, 24, 3, 43, 3), employer='Lind-Jast', department='Marketing', employee_id=796418731, vehicle_make='Isuzu', vehicle_model='Hombre Space', model_year=2000)
# M(ssn=105917777, first_name='Audi', last_name='Roach', gender='Female', language='Estonian', last_updated=datetime.datetime(2017, 5, 11, 1, 48, 32), created=datetime.datetime(2016, 5, 31, 0, 38, 13), employer='Bashirian-Lueilwitz', department='Engineering', employee_id=443328799, vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004)
# M(ssn=106351938, first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish', last_updated=datetime.datetime(2017, 10, 21, 1, 7, 28), created=datetime.datetime(2016, 9, 8, 4, 2, 12), employer='Windler, Marks and Haley', department='Services', employee_id=546271885, vehicle_make='GMC', vehicle_model='Sonoma Club', model_year=1992)
# M(ssn=106363293, first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin', last_updated=datetime.datetime(2017, 3, 18, 18, 24, 17), created=datetime.datetime(2016, 5, 16, 21, 21, 36), employer='Leffler-Hahn', department='Accounting', employee_id=315735282, vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008)
# M(ssn=110843641, first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento', last_updated=datetime.datetime(2017, 9, 4, 19, 2, 3), created=datetime.datetime(2016, 9, 12, 22, 50, 5), employer='Lueilwitz LLC', department='Marketing', employee_id=339146042, vehicle_make='Ford', vehicle_model='Mustang', model_year=1990)
# M(ssn=111351034, first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz', last_updated=datetime.datetime(2017, 3, 18, 14, 51, 4), created=datetime.datetime(2016, 8, 21, 7, 36, 17), employer='Davis Inc', department='Accounting', employee_id=390400385, vehicle_make='Ford', vehicle_model='Fiesta', model_year=2001)
# M(ssn=114066912, first_name='Jule', last_name='Velte', gender='Male', language='Dutch', last_updated=datetime.datetime(2018, 2, 5, 20, 48, 34), created=datetime.datetime(2016, 7, 15, 21, 58, 3), employer='Kunze LLC', department='Research and Development', employee_id=782612900, vehicle_make='Aston Martin', vehicle_model='DBS', model_year=2011)
# M(ssn=114660984, first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian', last_updated=datetime.datetime(2017, 6, 16, 17, 41, 33), created=datetime.datetime(2016, 5, 28, 20, 31, 25), employer='Mayert, Rice and Schmitt', department='Product Management', employee_id=858596488, vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998)
# M(ssn=114748701, first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic', last_updated=datetime.datetime(2017, 10, 30, 23, 54, 38), created=datetime.datetime(2016, 6, 4, 5, 18, 3), employer='Pouros LLC', department='Legal', employee_id=142589283, vehicle_make='Mercedes-Benz', vehicle_model='CL65 AMG', model_year=2009)
# M(ssn=116107235, first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari', last_updated=datetime.datetime(2017, 3, 10, 0, 31, 43), created=datetime.datetime(2016, 10, 17, 2, 11, 26), employer='Pfannerstill Group', department='Research and Development', employee_id=431532437, vehicle_make='Bugatti', vehicle_model='Veyron', model_year=2009)
# M(ssn=116774915, first_name='Herold', last_name='Fearon', gender='Male', language='Italian', last_updated=datetime.datetime(2017, 11, 21, 14, 25, 11), created=datetime.datetime(2016, 7, 3, 3, 55, 39), employer='Ryan Group', department='Sales', employee_id=88274517, vehicle_make='Buick', vehicle_model='Rainier', model_year=2004)
# M(ssn=117396617, first_name='Auroora', last_name='Yong', gender='Female', language='Swahili', last_updated=datetime.datetime(2017, 9, 1, 11, 58, 21), created=datetime.datetime(2016, 12, 1, 10, 11, 17), employer='Ritchie-Pagac', department='Business Development', employee_id=380095184, vehicle_make='Scion', vehicle_model='tC', model_year=2008)
# M(ssn=117786202, first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish', last_updated=datetime.datetime(2017, 11, 2, 2, 26, 10), created=datetime.datetime(2016, 4, 18, 0, 25, 1), employer='Kerluke-Dibbert', department='Services', employee_id=905121197, vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2007)
# M(ssn=118210357, first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian', last_updated=datetime.datetime(2017, 12, 13, 9, 36, 48), created=datetime.datetime(2016, 10, 24, 3, 40, 22), employer='Hane-Klocko', department='Human Resources', employee_id=272946273, vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1992)
# M(ssn=118957100, first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian', last_updated=datetime.datetime(2017, 4, 25, 7, 54, 46), created=datetime.datetime(2016, 1, 29, 12, 5, 28), employer='Ernser LLC', department='Services', employee_id=76466085, vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# M(ssn=119078817, first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian', last_updated=datetime.datetime(2017, 12, 24, 15, 31, 5), created=datetime.datetime(2016, 12, 6, 14, 16, 59), employer='Terry LLC', department='Accounting', employee_id=704864087, vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2005)
# M(ssn=120335535, first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi', last_updated=datetime.datetime(2017, 11, 11, 8, 53, 11), created=datetime.datetime(2016, 7, 10, 20, 49), employer='Rolfson, Price and Crooks', department='Business Development', employee_id=770255816, vehicle_make='Isuzu', vehicle_model='Trooper', model_year=1997)
# M(ssn=120984054, first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh', last_updated=datetime.datetime(2017, 12, 1, 17, 30, 55), created=datetime.datetime(2016, 7, 23, 15, 52, 53), employer='Romaguera, Welch and Haley', department='Engineering', employee_id=146523887, vehicle_make='Acura', vehicle_model='RL', model_year=2003)
# M(ssn=121983948, first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian', last_updated=datetime.datetime(2017, 8, 23, 16, 0, 57), created=datetime.datetime(2016, 6, 26, 23, 46, 48), employer='Paucek, Huels and Bauch', department='Accounting', employee_id=211452824, vehicle_make='Pontiac', vehicle_model='Montana', model_year=2002)
# M(ssn=123053229, first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian', last_updated=datetime.datetime(2017, 8, 16, 12, 8, 6), created=datetime.datetime(2016, 10, 23, 13, 32, 13), employer='Hayes-Trantow', department='Support', employee_id=72855255, vehicle_make='Jaguar', vehicle_model='X-Type', model_year=2003)
# M(ssn=123622832, first_name='Kare', last_name='Barhams', gender='Female', language='Tajik', last_updated=datetime.datetime(2017, 9, 11, 0, 2, 44), created=datetime.datetime(2016, 10, 22, 16, 14, 5), employer='Cruickshank, Legros and Keebler', department='Research and Development', employee_id=571590433, vehicle_make='Cadillac', vehicle_model='Catera', model_year=1999)
# M(ssn=127492473, first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole', last_updated=datetime.datetime(2017, 8, 31, 10, 3, 3), created=datetime.datetime(2016, 8, 29, 18, 48, 40), employer='Tromp-Leffler', department='Support', employee_id=26267170, vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2004)
# M(ssn=127684232, first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic', last_updated=datetime.datetime(2017, 3, 20, 6, 5, 42), created=datetime.datetime(2016, 8, 19, 16, 32, 21), employer='Kulas-Corwin', department='Sales', employee_id=780632027, vehicle_make='Scion', vehicle_model='xB', model_year=2004)
# M(ssn=127933548, first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao', last_updated=datetime.datetime(2017, 9, 10, 6, 24, 19), created=datetime.datetime(2016, 7, 23, 1, 30, 3), employer='MacGyver, Wiegand and Grant', department='Product Management', employee_id=774182531, vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=2007)
# M(ssn=128530369, first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian', last_updated=datetime.datetime(2017, 8, 10, 21, 18), created=datetime.datetime(2016, 12, 19, 21, 37, 6), employer='Vandervort, Bernier and Morissette', department='Human Resources', employee_id=144998615, vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# M(ssn=128537952, first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish', last_updated=datetime.datetime(2017, 8, 31, 16, 42, 23), created=datetime.datetime(2016, 7, 29, 3, 46, 26), employer='King-Donnelly', department='Training', employee_id=820573004, vehicle_make='Dodge', vehicle_model='Neon', model_year=1995)
# M(ssn=128566040, first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian', last_updated=datetime.datetime(2017, 8, 13, 2, 47, 15), created=datetime.datetime(2016, 3, 21, 8, 59, 56), employer='Harris Inc', department='Support', employee_id=537535536, vehicle_make='BMW', vehicle_model='M', model_year=2001)
# M(ssn=131814310, first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish', last_updated=datetime.datetime(2018, 3, 21, 12, 2, 31), created=datetime.datetime(2016, 2, 3, 23, 26, 27), employer='Gibson and Sons', department='Sales', employee_id=578173633, vehicle_make='Land Rover', vehicle_model='Range Rover Sport', model_year=2012)
# M(ssn=135869625, first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz', last_updated=datetime.datetime(2017, 12, 22, 4, 4, 28), created=datetime.datetime(2016, 2, 28, 23, 53, 17), employer='Hyatt LLC', department='Training', employee_id=969647102, vehicle_make='Toyota', vehicle_model='Tundra', model_year=2004)
# M(ssn=137131889, first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama', last_updated=datetime.datetime(2017, 12, 24, 9, 44, 10), created=datetime.datetime(2016, 3, 1, 19, 9, 29), employer='Schuster Group', department='Research and Development', employee_id=724728604, vehicle_make='Infiniti', vehicle_model='G', model_year=2005)
# M(ssn=138654579, first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish', last_updated=datetime.datetime(2017, 4, 17, 16, 30, 2), created=datetime.datetime(2016, 12, 17, 7, 7, 47), employer='Homenick-Beer', department='Product Management', employee_id=19334133, vehicle_make='Oldsmobile', vehicle_model='Achieva', model_year=1992)
# M(ssn=138671198, first_name='Pam', last_name='Tofful', gender='Female', language='Bislama', last_updated=datetime.datetime(2018, 3, 4, 8, 14, 31), created=datetime.datetime(2016, 9, 24, 1, 52, 46), employer='VonRueden-Torphy', department='Business Development', employee_id=106636122, vehicle_make='Lexus', vehicle_model='RX', model_year=2003)
# M(ssn=139945865, first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole', last_updated=datetime.datetime(2017, 8, 19, 16, 22, 52), created=datetime.datetime(2016, 9, 10, 21, 9, 28), employer='Gusikowski-Block', department='Legal', employee_id=411454732, vehicle_make='Volkswagen', vehicle_model='Cabriolet', model_year=1990)
# M(ssn=139996417, first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi', last_updated=datetime.datetime(2018, 1, 17, 17, 51, 12), created=datetime.datetime(2016, 12, 21, 14, 14, 20), employer='Pollich-Heathcote', department='Product Management', employee_id=122844710, vehicle_make='Volvo', vehicle_model='V70', model_year=2002)
# M(ssn=140339727, first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian', last_updated=datetime.datetime(2017, 9, 21, 23, 4, 48), created=datetime.datetime(2016, 1, 27, 9, 2, 26), employer='Bogisich Inc', department='Human Resources', employee_id=347172919, vehicle_make='Mitsubishi', vehicle_model='Lancer', model_year=2003)
# M(ssn=140588263, first_name='Tim', last_name='Bergin', gender='Female', language='Maori', last_updated=datetime.datetime(2017, 11, 12, 21, 41, 50), created=datetime.datetime(2016, 12, 14, 20, 27, 22), employer='Gutkowski Inc', department='Engineering', employee_id=834836768, vehicle_make='Volvo', vehicle_model='XC90', model_year=2009)
# M(ssn=141150543, first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin', last_updated=datetime.datetime(2017, 9, 27, 10, 29, 9), created=datetime.datetime(2016, 7, 17, 22, 40, 37), employer='Greenholt LLC', department='Sales', employee_id=845391800, vehicle_make='Toyota', vehicle_model='Corolla', model_year=2000)
# M(ssn=141889721, first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana', last_updated=datetime.datetime(2018, 1, 24, 20, 0, 4), created=datetime.datetime(2016, 12, 20, 0, 43, 43), employer='Hartmann Inc', department='Support', employee_id=267276512, vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011)
# M(ssn=142774616, first_name='Barron', last_name='Victoria', gender='Male', language='Assamese', last_updated=datetime.datetime(2017, 7, 16, 15, 12, 37), created=datetime.datetime(2016, 7, 30, 13, 28, 38), employer='Zboncak-Gulgowski', department='Marketing', employee_id=50368584, vehicle_make='Chevrolet', vehicle_model='Prizm', model_year=1999)
# M(ssn=142873416, first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik', last_updated=datetime.datetime(2017, 5, 3, 14, 26, 58), created=datetime.datetime(2016, 12, 26, 21, 18, 54), employer='Altenwerth-Emard', department='Marketing', employee_id=305847411, vehicle_make='Ford', vehicle_model='Thunderbird', model_year=2005)
# M(ssn=143174714, first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek', last_updated=datetime.datetime(2017, 7, 21, 18, 54, 47), created=datetime.datetime(2016, 2, 9, 6, 10, 21), employer='Cronin Inc', department='Business Development', employee_id=83106397, vehicle_make='Nissan', vehicle_model='Frontier', model_year=1999)
# M(ssn=145355124, first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi', last_updated=datetime.datetime(2018, 2, 20, 12, 47, 43), created=datetime.datetime(2016, 10, 3, 5, 18, 6), employer='Dibbert LLC', department='Support', employee_id=99620598, vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999)
# M(ssn=145783985, first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian', last_updated=datetime.datetime(2017, 6, 10, 6, 21, 46), created=datetime.datetime(2016, 9, 23, 15, 35, 52), employer='Tromp Inc', department='Research and Development', employee_id=63360383, vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1993)
# M(ssn=147331463, first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento', last_updated=datetime.datetime(2018, 2, 9, 4, 41, 58), created=datetime.datetime(2016, 5, 31, 23, 38, 59), employer='Greenholt-Gusikowski', department='Engineering', employee_id=166006875, vehicle_make='GMC', vehicle_model='Vandura G1500', model_year=1995)
# M(ssn=147478577, first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati', last_updated=datetime.datetime(2017, 4, 2, 18, 37, 59), created=datetime.datetime(2016, 12, 11, 3, 5, 36), employer='Tremblay, Jacobs and Swift', department='Training', employee_id=461648855, vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1996)
# M(ssn=147633462, first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin', last_updated=datetime.datetime(2018, 2, 2, 13, 16, 51), created=datetime.datetime(2016, 7, 17, 4, 28, 52), employer='Bashirian-Moen', department='Training', employee_id=519115041, vehicle_make='Ford', vehicle_model='Explorer', model_year=2005)
# M(ssn=149187272, first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento', last_updated=datetime.datetime(2017, 8, 31, 2, 41, 41), created=datetime.datetime(2016, 10, 21, 12, 17, 57), employer='Balistreri Inc', department='Sales', employee_id=928183627, vehicle_make='Mercedes-Benz', vehicle_model='500SEL', model_year=1992)
# M(ssn=149456482, first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian', last_updated=datetime.datetime(2017, 9, 2, 5, 13, 32), created=datetime.datetime(2016, 2, 23, 16, 20, 59), employer='Eichmann, Quigley and Macejkovic', department='Business Development', employee_id=488059597, vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1995)
# M(ssn=150646357, first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian', last_updated=datetime.datetime(2018, 2, 14, 23, 35, 53), created=datetime.datetime(2016, 1, 28, 3, 19, 50), employer='Bosco-Kunde', department='Services', employee_id=551726090, vehicle_make='Cadillac', vehicle_model='Escalade', model_year=2000)
# M(ssn=150893343, first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha', last_updated=datetime.datetime(2017, 6, 4, 1, 39, 16), created=datetime.datetime(2016, 4, 23, 14, 7, 49), employer='Ratke-Raynor', department='Legal', employee_id=606687797, vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993)
# M(ssn=151543946, first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali', last_updated=datetime.datetime(2018, 2, 8, 11, 16, 12), created=datetime.datetime(2016, 10, 19, 8, 22, 59), employer='Bergstrom-Boyle', department='Marketing', employee_id=723121170, vehicle_make='Ford', vehicle_model='Probe', model_year=1996)
# M(ssn=151781397, first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho', last_updated=datetime.datetime(2017, 7, 8, 4, 22, 30), created=datetime.datetime(2016, 6, 11, 0, 28, 10), employer='Schinner, Swaniawski and Carter', department='Human Resources', employee_id=933103060, vehicle_make='BMW', vehicle_model='M5', model_year=2000)
# M(ssn=152713526, first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish', last_updated=datetime.datetime(2018, 2, 25, 4, 17, 50), created=datetime.datetime(2016, 10, 8, 19, 49, 4), employer='Little, Hagenes and McKenzie', department='Training', employee_id=759906937, vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2001)
# M(ssn=153671309, first_name='Annelise', last_name='Yushin', gender='Female', language='French', last_updated=datetime.datetime(2017, 8, 16, 12, 3, 37), created=datetime.datetime(2016, 12, 22, 19, 37, 39), employer='Gerlach, Bahringer and Rutherford', department='Accounting', employee_id=955604381, vehicle_make='Ford', vehicle_model='Taurus', model_year=1998)
# M(ssn=154177912, first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi', last_updated=datetime.datetime(2017, 4, 19, 22, 8, 24), created=datetime.datetime(2016, 1, 29, 12, 43, 45), employer='Gorczany LLC', department='Training', employee_id=628983936, vehicle_make='Nissan', vehicle_model='Armada', model_year=2005)
# M(ssn=156187547, first_name='Trey', last_name='Payne', gender='Male', language='West Frisian', last_updated=datetime.datetime(2017, 9, 10, 22, 58, 31), created=datetime.datetime(2016, 10, 20, 19, 49, 24), employer='Little, Powlowski and Witting', department='Business Development', employee_id=424459617, vehicle_make='Subaru', vehicle_model='Legacy', model_year=2011)
# M(ssn=156916848, first_name='Carol', last_name='Cromar', gender='Female', language='Amharic', last_updated=datetime.datetime(2017, 8, 30, 22, 29, 10), created=datetime.datetime(2016, 5, 7, 6, 45, 32), employer='King LLC', department='Research and Development', employee_id=394026042, vehicle_make='Acura', vehicle_model='TL', model_year=2005)
# M(ssn=157179982, first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish', last_updated=datetime.datetime(2017, 4, 17, 9, 11, 49), created=datetime.datetime(2016, 3, 17, 0, 22, 29), employer='Konopelski-Vandervort', department='Legal', employee_id=878332368, vehicle_make='Audi', vehicle_model='Q7', model_year=2007)
# M(ssn=157387090, first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans', last_updated=datetime.datetime(2017, 3, 24, 8, 58, 33), created=datetime.datetime(2016, 9, 15, 16, 11, 12), employer='Reichel Group', department='Training', employee_id=105605387, vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=2005)
# M(ssn=157515269, first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi', last_updated=datetime.datetime(2017, 11, 4, 20, 16, 50), created=datetime.datetime(2016, 6, 17, 10, 3, 2), employer='Gerhold-Marquardt', department='Research and Development', employee_id=256013938, vehicle_make='BMW', vehicle_model='Z3', model_year=1996)
# M(ssn=161369710, first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish', last_updated=datetime.datetime(2017, 7, 3, 6, 26, 41), created=datetime.datetime(2016, 6, 9, 5, 30, 33), employer='Greenholt-Hermiston', department='Business Development', employee_id=669841280, vehicle_make='Mercedes-Benz', vehicle_model='SLK-Class', model_year=1999)
# M(ssn=161534778, first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz', last_updated=datetime.datetime(2017, 12, 3, 11, 9, 18), created=datetime.datetime(2016, 12, 9, 18, 37, 55), employer='Oberbrunner, Donnelly and Gibson', department='Human Resources', employee_id=832548521, vehicle_make='Ford', vehicle_model='Mustang', model_year=1995)
# M(ssn=163688070, first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino', last_updated=datetime.datetime(2017, 9, 6, 16, 56, 6), created=datetime.datetime(2016, 10, 23, 1, 47, 51), employer='Roberts Group', department='Product Management', employee_id=76620387, vehicle_make='Lincoln', vehicle_model='Continental', model_year=1998)
# M(ssn=163981022, first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian', last_updated=datetime.datetime(2017, 3, 26, 4, 2, 28), created=datetime.datetime(2016, 3, 22, 11, 24, 33), employer='Olson-Lynch', department='Business Development', employee_id=507113609, vehicle_make='Honda', vehicle_model='Civic', model_year=2012)
# M(ssn=164119849, first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian', last_updated=datetime.datetime(2017, 6, 24, 10, 17, 58), created=datetime.datetime(2016, 4, 20, 11, 9, 5), employer='Quitzon, Rempel and Hane', department='Business Development', employee_id=34767523, vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2001)
# M(ssn=166104488, first_name='Lester', last_name='Keyson', gender='Male', language='Bislama', last_updated=datetime.datetime(2017, 8, 14, 16, 48, 43), created=datetime.datetime(2016, 7, 2, 8, 33, 48), employer='Carroll, Konopelski and Wunsch', department='Research and Development', employee_id=434797129, vehicle_make='Cadillac', vehicle_model='DTS', model_year=2008)
# M(ssn=167392377, first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese', last_updated=datetime.datetime(2017, 10, 31, 22, 27, 7), created=datetime.datetime(2016, 2, 3, 10, 32, 1), employer='Howell LLC', department='Business Development', employee_id=702399476, vehicle_make='GMC', vehicle_model='3500', model_year=1998)
# M(ssn=168025324, first_name='Dane', last_name='Cornick', gender='Male', language='Tajik', last_updated=datetime.datetime(2018, 1, 4, 21, 50, 39), created=datetime.datetime(2016, 1, 29, 15, 31, 40), employer='Johnson Inc', department='Services', employee_id=347741883, vehicle_make='Volkswagen', vehicle_model='Fox', model_year=1989)
# M(ssn=168198754, first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian', last_updated=datetime.datetime(2017, 6, 10, 3, 48, 51), created=datetime.datetime(2016, 9, 27, 15, 4, 24), employer='Corwin and Sons', department='Legal', employee_id=158160997, vehicle_make='Toyota', vehicle_model='MR2', model_year=1993)
# M(ssn=168896661, first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum', last_updated=datetime.datetime(2017, 7, 17, 2, 59, 15), created=datetime.datetime(2016, 4, 30, 9, 17, 39), employer='Toy-Jakubowski', department='Engineering', employee_id=178085199, vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1964)
# M(ssn=170653388, first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese', last_updated=datetime.datetime(2017, 3, 5, 0, 46, 26), created=datetime.datetime(2016, 6, 15, 5, 37, 27), employer='Murphy, Windler and Bartoletti', department='Legal', employee_id=26976472, vehicle_make='Dodge', vehicle_model='Caravan', model_year=2010)
# M(ssn=171277781, first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao', last_updated=datetime.datetime(2017, 3, 5, 9, 35, 8), created=datetime.datetime(2016, 9, 23, 3, 10, 37), employer='Batz Inc', department='Support', employee_id=492738721, vehicle_make='Ford', vehicle_model='Mustang', model_year=1985)
# M(ssn=172237739, first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz', last_updated=datetime.datetime(2018, 3, 2, 23, 30, 36), created=datetime.datetime(2016, 5, 12, 16, 1, 48), employer='Jast and Sons', department='Services', employee_id=386141294, vehicle_make='Mazda', vehicle_model='Mazdaspeed 3', model_year=2011)
# M(ssn=172774263, first_name='Alex', last_name='Udie', gender='Male', language='French', last_updated=datetime.datetime(2017, 10, 11, 13, 32, 41), created=datetime.datetime(2016, 9, 10, 9, 18, 50), employer='Roberts LLC', department='Research and Development', employee_id=912028080, vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# M(ssn=173997372, first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish', last_updated=datetime.datetime(2018, 3, 3, 15, 18, 26), created=datetime.datetime(2016, 10, 26, 15, 24, 37), employer='Zulauf, Hudson and Wisozk', department='Research and Development', employee_id=391896194, vehicle_make='Kia', vehicle_model='Sephia', model_year=1997)
# M(ssn=174519992, first_name='Drucie', last_name='Travers', gender='Female', language='Swati', last_updated=datetime.datetime(2017, 3, 3, 19, 42, 18), created=datetime.datetime(2016, 5, 17, 23, 32, 25), employer='Jast-Quitzon', department='Human Resources', employee_id=675707294, vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1994)
# M(ssn=174872537, first_name='Benton', last_name='Nolte', gender='Male', language='Persian', last_updated=datetime.datetime(2017, 9, 30, 14, 38, 36), created=datetime.datetime(2016, 8, 1, 11, 19, 25), employer='Green-Waelchi', department='Engineering', employee_id=297065788, vehicle_make='Ford', vehicle_model='Taurus', model_year=1991)
# M(ssn=176995851, first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan', last_updated=datetime.datetime(2017, 4, 1, 20, 14, 53), created=datetime.datetime(2016, 12, 3, 15, 8, 4), employer='MacGyver-Hartmann', department='Accounting', employee_id=774207310, vehicle_make='Jeep', vehicle_model='Commander', model_year=2007)
# M(ssn=179882790, first_name='Errick', last_name='Charsley', gender='Male', language='Japanese', last_updated=datetime.datetime(2017, 3, 23, 1, 30, 12), created=datetime.datetime(2016, 3, 6, 13, 15, 20), employer='McGlynn LLC', department='Support', employee_id=354393230, vehicle_make='Chevrolet', vehicle_model='Malibu', model_year=2013)
# M(ssn=181074434, first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan', last_updated=datetime.datetime(2017, 10, 7, 7, 52, 10), created=datetime.datetime(2016, 11, 11, 20, 19, 19), employer='Little, Herzog and Mertz', department='Legal', employee_id=459164509, vehicle_make='Chevrolet', vehicle_model='Impala SS', model_year=1995)
# M(ssn=181288337, first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan', last_updated=datetime.datetime(2017, 11, 30, 23, 28), created=datetime.datetime(2016, 4, 27, 20, 53, 49), employer='Kertzmann-Reichel', department='Research and Development', employee_id=670581933, vehicle_make='GMC', vehicle_model='Canyon', model_year=2004)
# M(ssn=181886077, first_name='Ebba', last_name='Wozencroft', gender='Female', language='German', last_updated=datetime.datetime(2017, 8, 16, 21, 35, 50), created=datetime.datetime(2016, 9, 15, 10, 22, 56), employer='Douglas, Funk and Schowalter', department='Services', employee_id=772512148, vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2008)
# M(ssn=182155082, first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili', last_updated=datetime.datetime(2017, 10, 2, 6, 22, 27), created=datetime.datetime(2016, 10, 16, 12, 16, 53), employer='Bayer-Kunze', department='Support', employee_id=866996270, vehicle_make='Mercedes-Benz', vehicle_model='S-Class', model_year=1988)
# M(ssn=182814541, first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish', last_updated=datetime.datetime(2017, 7, 5, 10, 19, 41), created=datetime.datetime(2016, 7, 23, 3, 16, 13), employer='Kiehn, Hansen and Will', department='Support', employee_id=948005696, vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=1997)
# M(ssn=183105024, first_name='Curran', last_name='Squires', gender='Male', language='Romanian', last_updated=datetime.datetime(2017, 11, 3, 0, 36, 20), created=datetime.datetime(2016, 9, 8, 5, 10, 46), employer='Kling-Howe', department='Research and Development', employee_id=717470887, vehicle_make='Maserati', vehicle_model='Spyder', model_year=1991)
# M(ssn=184606243, first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin', last_updated=datetime.datetime(2018, 2, 26, 15, 42, 50), created=datetime.datetime(2016, 6, 16, 15, 17, 46), employer='Quitzon-Morissette', department='Product Management', employee_id=815434446, vehicle_make='Ford', vehicle_model='Mustang', model_year=1998)
# M(ssn=184841003, first_name='Bary', last_name='Buzin', gender='Male', language='Aymara', last_updated=datetime.datetime(2017, 10, 15, 21, 11, 17), created=datetime.datetime(2016, 11, 17, 18, 52, 56), employer='Bergstrom-Daniel', department='Marketing', employee_id=317381298, vehicle_make='Mercury', vehicle_model='Mystique', model_year=1997)
# M(ssn=184945241, first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati', last_updated=datetime.datetime(2017, 3, 28, 16, 56, 35), created=datetime.datetime(2016, 6, 3, 5, 38, 20), employer='Lubowitz-Franecki', department='Product Management', employee_id=685287750, vehicle_make='Audi', vehicle_model='90', model_year=1991)
# M(ssn=185849868, first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho', last_updated=datetime.datetime(2017, 7, 1, 13, 56, 28), created=datetime.datetime(2016, 8, 8, 8, 4, 45), employer='Quitzon, Stiedemann and Breitenberg', department='Services', employee_id=761399493, vehicle_make='Mercury', vehicle_model='Sable', model_year=2001)
# M(ssn=186657773, first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi', last_updated=datetime.datetime(2017, 6, 9, 12, 34, 32), created=datetime.datetime(2016, 9, 17, 22, 55, 15), employer='Turner-Connelly', department='Research and Development', employee_id=921687621, vehicle_make='Mitsubishi', vehicle_model='Precis', model_year=1990)
# M(ssn=188209317, first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai', last_updated=datetime.datetime(2017, 12, 26, 5, 29, 23), created=datetime.datetime(2016, 6, 5, 4, 26, 52), employer='Kling, Prosacco and Wisoky', department='Accounting', employee_id=770491080, vehicle_make='Chevrolet', vehicle_model='Avalanche 2500', model_year=2003)
# M(ssn=188404336, first_name='Belita', last_name='Camolli', gender='Female', language='Telugu', last_updated=datetime.datetime(2017, 12, 27, 3, 41, 46), created=datetime.datetime(2016, 6, 30, 2, 48, 10), employer="Von, O'Kon and Runolfsdottir", department='Research and Development', employee_id=346414700, vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1985)
# M(ssn=189265696, first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin', last_updated=datetime.datetime(2017, 8, 8, 19, 29, 59), created=datetime.datetime(2016, 9, 9, 19, 38, 18), employer='McLaughlin-Botsford', department='Business Development', employee_id=602450272, vehicle_make='BMW', vehicle_model='8 Series', model_year=1995)
# M(ssn=190056987, first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian', last_updated=datetime.datetime(2017, 6, 6, 20, 51, 23), created=datetime.datetime(2016, 2, 17, 12, 0, 16), employer='Smitham-Blick', department='Engineering', employee_id=73918459, vehicle_make='Subaru', vehicle_model='Legacy', model_year=1990)
# M(ssn=190534517, first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili', last_updated=datetime.datetime(2018, 2, 12, 20, 26, 30), created=datetime.datetime(2016, 4, 15, 16, 42, 18), employer='Reilly and Sons', department='Product Management', employee_id=2155545, vehicle_make='Hyundai', vehicle_model='Sonata', model_year=1993)
# M(ssn=191153194, first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai', last_updated=datetime.datetime(2017, 7, 27, 9, 14, 42), created=datetime.datetime(2016, 5, 23, 13, 52, 39), employer='Keeling, Hansen and Mertz', department='Training', employee_id=863420084, vehicle_make='Mercury', vehicle_model='Grand Marquis', model_year=2009)
# M(ssn=192540695, first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori', last_updated=datetime.datetime(2017, 3, 18, 6, 5, 59), created=datetime.datetime(2016, 11, 16, 1, 58, 55), employer='Mante Inc', department='Business Development', employee_id=398018810, vehicle_make='Volvo', vehicle_model='C70', model_year=1998)
# M(ssn=195235731, first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese', last_updated=datetime.datetime(2017, 5, 22, 16, 24, 23), created=datetime.datetime(2016, 10, 23, 11, 15, 3), employer='Hodkiewicz, Rau and Ryan', department='Marketing', employee_id=292776451, vehicle_make='Saturn', vehicle_model='Outlook', model_year=2007)
# M(ssn=199450804, first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana', last_updated=datetime.datetime(2017, 6, 23, 12, 59, 20), created=datetime.datetime(2016, 11, 7, 0, 25, 12), employer='Farrell and Sons', department='Product Management', employee_id=853648779, vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2003)
# M(ssn=199544639, first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali', last_updated=datetime.datetime(2018, 2, 23, 10, 14, 54), created=datetime.datetime(2016, 4, 5, 5, 11, 13), employer='Heathcote-Torp', department='Product Management', employee_id=772681193, vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2006)
# M(ssn=200817151, first_name='Merilyn', last_name='Tink', gender='Female', language='Bengali', last_updated=datetime.datetime(2017, 11, 19, 13, 58, 42), created=datetime.datetime(2016, 7, 31, 19, 2, 12), employer='Hilpert, Kassulke and Gutkowski', department='Research and Development', employee_id=26484055, vehicle_make='Mitsubishi', vehicle_model='Tredia', model_year=1985)
# M(ssn=201531249, first_name='Jammal', last_name='Dohmer', gender='Male', language='Danish', last_updated=datetime.datetime(2017, 11, 25, 14, 19, 29), created=datetime.datetime(2016, 10, 7, 18, 42, 12), employer="Will, Lemke and O'Hara", department='Marketing', employee_id=687719884, vehicle_make='Acura', vehicle_model='NSX', model_year=1996)
# M(ssn=202841146, first_name='Dore', last_name='Woodrup', gender='Male', language='Afrikaans', last_updated=datetime.datetime(2017, 4, 1, 22, 1, 53), created=datetime.datetime(2016, 7, 21, 8, 10, 25), employer='Schuppe-Dickinson', department='Services', employee_id=478932065, vehicle_make='Chrysler', vehicle_model='LHS', model_year=2000)
# M(ssn=203357648, first_name='Budd', last_name='Artiss', gender='Male', language='Norwegian', last_updated=datetime.datetime(2017, 12, 1, 14, 42, 14), created=datetime.datetime(2016, 8, 2, 14, 24, 12), employer='Kling-Graham', department='Marketing', employee_id=84055205, vehicle_make='Volvo', vehicle_model='960', model_year=1992)
# M(ssn=205697375, first_name='Cacilia', last_name='Kneesha', gender='Female', language='Indonesian', last_updated=datetime.datetime(2018, 2, 27, 13, 25, 24), created=datetime.datetime(2016, 5, 19, 12, 10, 37), employer='MacGyver, Armstrong and Murray', department='Research and Development', employee_id=688311842, vehicle_make='Subaru', vehicle_model='Outback', model_year=2011)
# M(ssn=205872423, first_name='Oralla', last_name='Kearle', gender='Female', language='Zulu', last_updated=datetime.datetime(2018, 1, 1, 8, 17, 27), created=datetime.datetime(2016, 2, 16, 23, 45, 38), employer='Goodwin-Oberbrunner', department='Accounting', employee_id=70291024, vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=1999)
# M(ssn=206286674, first_name='Con', last_name='Mansbridge', gender='Male', language='Haitian Creole', last_updated=datetime.datetime(2017, 10, 14, 6, 32, 53), created=datetime.datetime(2016, 8, 1, 8, 2, 52), employer='Russel-Terry', department='Engineering', employee_id=700439540, vehicle_make='Mitsubishi', vehicle_model='Chariot', model_year=1994)
# M(ssn=206838848, first_name='Ardyth', last_name='Arger', gender='Female', language='Gagauz', last_updated=datetime.datetime(2017, 11, 8, 14, 57, 17), created=datetime.datetime(2016, 4, 11, 17, 40, 42), employer='Hickle, Beatty and McCullough', department='Business Development', employee_id=957755368, vehicle_make='Volvo', vehicle_model='S60', model_year=2011)
# M(ssn=208805879, first_name='Rockie', last_name='Fryd', gender='Male', language='Korean', last_updated=datetime.datetime(2017, 10, 16, 21, 39, 4), created=datetime.datetime(2016, 3, 31, 17, 4, 29), employer='Volkman-King', department='Training', employee_id=295040096, vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2009)
# M(ssn=209508146, first_name='Kenna', last_name='Meryett', gender='Female', language='Czech', last_updated=datetime.datetime(2018, 3, 13, 17, 52, 16), created=datetime.datetime(2016, 4, 10, 7, 14, 25), employer='Senger, Fay and Schuppe', department='Marketing', employee_id=59734435, vehicle_make='Chevrolet', vehicle_model='Sportvan G20', model_year=1992)
# M(ssn=209584708, first_name='Stephanus', last_name='Creboe', gender='Male', language='Latvian', last_updated=datetime.datetime(2018, 2, 8, 21, 22, 2), created=datetime.datetime(2016, 6, 17, 9, 21, 14), employer='Lesch, Hartmann and Leffler', department='Engineering', employee_id=326936796, vehicle_make='Buick', vehicle_model='LaCrosse', model_year=2009)
# M(ssn=210914729, first_name='Tamarra', last_name='Minchella', gender='Female', language='Greek', last_updated=datetime.datetime(2017, 7, 11, 8, 17, 40), created=datetime.datetime(2016, 12, 4, 0, 41, 8), employer='Weber, Reynolds and Brakus', department='Training', employee_id=260100410, vehicle_make='Acura', vehicle_model='Integra', model_year=1997)
# M(ssn=211041734, first_name='Jeana', last_name='Girardeau', gender='Female', language='Dzongkha', last_updated=datetime.datetime(2018, 3, 11, 20, 29, 12), created=datetime.datetime(2016, 8, 30, 15, 59, 14), employer='Renner LLC', department='Services', employee_id=296760360, vehicle_make='Ford', vehicle_model='E-Series', model_year=2011)
# M(ssn=211135247, first_name='Wes', last_name='Weinberg', gender='Male', language='French', last_updated=datetime.datetime(2018, 2, 22, 16, 37, 12), created=datetime.datetime(2016, 12, 20, 3, 14, 56), employer='Lind and Sons', department='Services', employee_id=934909831, vehicle_make='Mercedes-Benz', vehicle_model='SLR McLaren', model_year=2005)
# M(ssn=211155182, first_name='Gene', last_name='Bassilashvili', gender='Female', language='Swedish', last_updated=datetime.datetime(2017, 4, 15, 16, 17, 42), created=datetime.datetime(2016, 3, 17, 19, 14, 56), employer='Sawayn, Marvin and Rempel', department='Research and Development', employee_id=746068283, vehicle_make='Chrysler', vehicle_model='Town & Country', model_year=2010)
# M(ssn=211196826, first_name='Noni', last_name='Meynell', gender='Female', language='Portuguese', last_updated=datetime.datetime(2018, 2, 12, 4, 33, 14), created=datetime.datetime(2016, 8, 25, 22, 0, 15), employer='Feil, Wunsch and Cassin', department='Human Resources', employee_id=453457627, vehicle_make='Ford', vehicle_model='Econoline E150', model_year=1996)
# M(ssn=212411496, first_name='Agnese', last_name='Lawes', gender='Female', language='Tamil', last_updated=datetime.datetime(2017, 7, 7, 20, 29, 9), created=datetime.datetime(2016, 10, 27, 12, 47, 10), employer='Hills-Luettgen', department='Engineering', employee_id=496662355, vehicle_make='Volkswagen', vehicle_model='Eurovan', model_year=1995)
# M(ssn=213281395, first_name='Catlaina', last_name='Patullo', gender='Female', language='Bengali', last_updated=datetime.datetime(2017, 6, 4, 4, 51, 16), created=datetime.datetime(2016, 6, 11, 0, 6, 58), employer='Larson and Sons', department='Sales', employee_id=183961077, vehicle_make='Ford', vehicle_model='Mustang', model_year=2002)
# M(ssn=214291189, first_name='Chandler', last_name='Gonsalvo', gender='Male', language='Haitian Creole', last_updated=datetime.datetime(2018, 2, 16, 8, 10, 36), created=datetime.datetime(2016, 6, 2, 0, 48, 2), employer='Sipes LLC', department='Business Development', employee_id=135040342, vehicle_make='Kia', vehicle_model='Sedona', model_year=2011)
# M(ssn=214968581, first_name='Earlie', last_name='de Nore', gender='Male', language='Georgian', last_updated=datetime.datetime(2017, 4, 30, 7, 25, 59), created=datetime.datetime(2016, 8, 18, 0, 21, 7), employer='Aufderhar, Trantow and Goodwin', department='Marketing', employee_id=708647485, vehicle_make='Kia', vehicle_model='Borrego', model_year=2009)
# M(ssn=214997584, first_name='Barny', last_name='Witherden', gender='Male', language='Czech', last_updated=datetime.datetime(2018, 2, 22, 11, 32, 50), created=datetime.datetime(2016, 7, 14, 3, 30, 15), employer='Emmerich, Emmerich and Mertz', department='Business Development', employee_id=139720741, vehicle_make='Saturn', vehicle_model='Outlook', model_year=2010)
# M(ssn=216893812, first_name='Florian', last_name='Jaze', gender='Male', language='Croatian', last_updated=datetime.datetime(2018, 3, 11, 20, 2, 23), created=datetime.datetime(2016, 7, 28, 7, 3, 44), employer='Quitzon Inc', department='Human Resources', employee_id=970142691, vehicle_make='Maybach', vehicle_model='Landaulet', model_year=2012)
# M(ssn=217713922, first_name='Hayes', last_name='Vallentin', gender='Male', language='Bengali', last_updated=datetime.datetime(2017, 11, 11, 19, 44, 46), created=datetime.datetime(2016, 3, 4, 12, 33, 51), employer='Nienow-Hegmann', department='Training', employee_id=816888800, vehicle_make='Volkswagen', vehicle_model='Corrado', model_year=1990)
# M(ssn=217815416, first_name='Gusta', last_name='Cruise', gender='Female', language='Tsonga', last_updated=datetime.datetime(2017, 12, 27, 18, 15, 59), created=datetime.datetime(2016, 11, 20, 2, 39, 48), employer='Gislason-Padberg', department='Sales', employee_id=208472919, vehicle_make='Ford', vehicle_model='Mustang', model_year=2005)
# M(ssn=218144448, first_name='Keary', last_name='Druhan', gender='Male', language='Dutch', last_updated=datetime.datetime(2017, 7, 22, 9, 16, 18), created=datetime.datetime(2016, 6, 29, 6, 28, 37), employer='Cormier, Weimann and Erdman', department='Accounting', employee_id=728208288, vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1999)
# M(ssn=218259873, first_name='Westbrooke', last_name='Succamore', gender='Male', language='Fijian', last_updated=datetime.datetime(2017, 5, 11, 20, 22, 10), created=datetime.datetime(2016, 3, 11, 12, 58, 1), employer='Mraz, Stokes and MacGyver', department='Legal', employee_id=406893978, vehicle_make='Honda', vehicle_model='Prelude', model_year=1997)
# M(ssn=218311615, first_name='Trenton', last_name='Eggerton', gender='Male', language='Dari', last_updated=datetime.datetime(2017, 8, 3, 8, 57, 27), created=datetime.datetime(2016, 5, 14, 20, 4, 1), employer='Stokes-Hayes', department='Marketing', employee_id=501906989, vehicle_make='Mitsubishi', vehicle_model='3000GT', model_year=1996)
# M(ssn=218497300, first_name='Justinn', last_name='Sherebrooke', gender='Female', language='English', last_updated=datetime.datetime(2017, 12, 22, 19, 46, 19), created=datetime.datetime(2016, 9, 17, 5, 14, 16), employer='Johns, Corkery and Feeney', department='Services', employee_id=227439070, vehicle_make='Plymouth', vehicle_model='Neon', model_year=1995)
# M(ssn=220160476, first_name='Baxy', last_name='Brothwood', gender='Male', language='Kyrgyz', last_updated=datetime.datetime(2017, 3, 9, 16, 48, 29), created=datetime.datetime(2016, 7, 4, 6, 40, 49), employer='Hirthe, Doyle and Harvey', department='Training', employee_id=131135326, vehicle_make='Lexus', vehicle_model='LX', model_year=2011)
# M(ssn=220380208, first_name='Jess', last_name='Fulun', gender='Female', language='Gagauz', last_updated=datetime.datetime(2017, 11, 10, 15, 6, 25), created=datetime.datetime(2016, 10, 28, 19, 34, 21), employer='Brekke, Grady and Ruecker', department='Human Resources', employee_id=662984352, vehicle_make='Ford', vehicle_model='Lightning', model_year=1994)
# M(ssn=223679203, first_name='Markus', last_name='Radband', gender='Male', language='Bosnian', last_updated=datetime.datetime(2017, 8, 4, 12, 57, 4), created=datetime.datetime(2016, 12, 2, 13, 29, 54), employer='Langosh, Blick and Bechtelar', department='Product Management', employee_id=556679606, vehicle_make='Chevrolet', vehicle_model='Impala', model_year=2002)
# ...
# M(ssn=853118953, first_name='Brice', last_name='Kyd', gender='Male', language='Dari', last_updated=datetime.datetime(2017, 12, 30, 0, 36, 43), created=datetime.datetime(2016, 12, 24, 23, 34, 4), employer='Moen Inc', department='Sales', employee_id=981092646, vehicle_make='Pontiac', vehicle_model='Fiero', model_year=1987)
# M(ssn=853473648, first_name='Olag', last_name='Belhome', gender='Male', language='Maltese', last_updated=datetime.datetime(2017, 11, 24, 19, 37, 50), created=datetime.datetime(2016, 4, 22, 21, 36, 41), employer='Barrows Inc', department='Product Management', employee_id=63741043, vehicle_make='Infiniti', vehicle_model='I', model_year=2003)
# M(ssn=854687635, first_name='Eyde', last_name='McCunn', gender='Female', language='Moldovan', last_updated=datetime.datetime(2017, 5, 16, 14, 22, 39), created=datetime.datetime(2016, 4, 29, 5, 3, 11), employer='Thiel-Murray', department='Support', employee_id=962035605, vehicle_make='Pontiac', vehicle_model='Grand Prix', model_year=1991)
# M(ssn=854712983, first_name='Rikki', last_name='Loveland', gender='Male', language='Dutch', last_updated=datetime.datetime(2017, 9, 6, 20, 53, 9), created=datetime.datetime(2016, 11, 7, 5, 47, 14), employer='Blanda-Ferry', department='Product Management', employee_id=749087432, vehicle_make='Subaru', vehicle_model='SVX', model_year=1993)
# M(ssn=854795334, first_name='Bevan', last_name='Kolczynski', gender='Male', language='Swahili', last_updated=datetime.datetime(2017, 8, 29, 17, 57, 56), created=datetime.datetime(2016, 3, 27, 18, 30, 18), employer='Dietrich Inc', department='Business Development', employee_id=791998214, vehicle_make='Jeep', vehicle_model='Cherokee', model_year=1996)
# M(ssn=856279112, first_name='Virgilio', last_name='Kirrage', gender='Male', language='Pashto', last_updated=datetime.datetime(2017, 12, 25, 10, 25, 28), created=datetime.datetime(2016, 3, 24, 4, 1, 59), employer='Lakin and Sons', department='Accounting', employee_id=414723930, vehicle_make='BMW', vehicle_model='3 Series', model_year=2011)
# M(ssn=856674080, first_name='Aggy', last_name='Cobley', gender='Female', language='Dhivehi', last_updated=datetime.datetime(2018, 3, 13, 21, 23, 9), created=datetime.datetime(2016, 6, 22, 3, 53, 18), employer='Kassulke, Ritchie and Braun', department='Accounting', employee_id=61382466, vehicle_make='Dodge', vehicle_model='Grand Caravan', model_year=2007)
# M(ssn=857375902, first_name='Jenni', last_name='Swinyard', gender='Female', language='Hindi', last_updated=datetime.datetime(2018, 1, 20, 14, 44, 7), created=datetime.datetime(2016, 10, 23, 21, 56, 28), employer='Swaniawski Group', department='Services', employee_id=442276418, vehicle_make='Lotus', vehicle_model='Esprit', model_year=1996)
# M(ssn=858037735, first_name='Allayne', last_name='Wardingley', gender='Male', language='Kazakh', last_updated=datetime.datetime(2017, 4, 30, 8, 14, 24), created=datetime.datetime(2016, 9, 4, 8, 24, 3), employer='Stark-Pouros', department='Training', employee_id=537456817, vehicle_make='Porsche', vehicle_model='944', model_year=1984)
# M(ssn=860892570, first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish', last_updated=datetime.datetime(2017, 4, 15, 11, 12, 57), created=datetime.datetime(2016, 6, 22, 23, 23, 9), employer='Reinger Inc', department='Engineering', employee_id=802005731, vehicle_make='Dodge', vehicle_model='Dakota', model_year=2007)
# M(ssn=861506716, first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian', last_updated=datetime.datetime(2018, 3, 30, 21, 7, 8), created=datetime.datetime(2016, 9, 16, 9, 12, 34), employer='Stokes Inc', department='Training', employee_id=126635955, vehicle_make='BMW', vehicle_model='M5', model_year=2007)
# M(ssn=862200653, first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish', last_updated=datetime.datetime(2017, 5, 3, 14, 37, 42), created=datetime.datetime(2016, 2, 4, 14, 11, 40), employer='Dicki, Green and White', department='Services', employee_id=871017676, vehicle_make='Mazda', vehicle_model='B-Series', model_year=2002)
# M(ssn=866181440, first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento', last_updated=datetime.datetime(2017, 5, 31, 4, 28, 19), created=datetime.datetime(2016, 2, 2, 17, 47, 22), employer='Bartoletti Inc', department='Support', employee_id=777239839, vehicle_make='Volvo', vehicle_model='S60', model_year=2002)
# M(ssn=866530625, first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian', last_updated=datetime.datetime(2018, 2, 24, 20, 22, 43), created=datetime.datetime(2016, 12, 15, 22, 59, 20), employer='Douglas-Breitenberg', department='Business Development', employee_id=636285198, vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1997)
# M(ssn=867116007, first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam', last_updated=datetime.datetime(2018, 1, 25, 4, 2, 4), created=datetime.datetime(2016, 10, 31, 14, 12, 16), employer='Nitzsche-Walker', department='Engineering', employee_id=505681388, vehicle_make='Volvo', vehicle_model='S80', model_year=2001)
# M(ssn=867136844, first_name='Clo', last_name='Skacel', gender='Female', language='Armenian', last_updated=datetime.datetime(2017, 10, 31, 17, 48, 23), created=datetime.datetime(2016, 7, 17, 9, 50, 7), employer='Crist, Leuschke and Grimes', department='Legal', employee_id=98398802, vehicle_make='Land Rover', vehicle_model='Range Rover', model_year=1986)
# M(ssn=867882360, first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha', last_updated=datetime.datetime(2018, 3, 11, 16, 42, 31), created=datetime.datetime(2016, 11, 4, 18, 34, 52), employer='Emard Inc', department='Business Development', employee_id=492589434, vehicle_make='Ford', vehicle_model='F-Series', model_year=1987)
# M(ssn=868321805, first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian', last_updated=datetime.datetime(2017, 9, 29, 17, 46, 17), created=datetime.datetime(2016, 11, 14, 1, 26, 32), employer='Abshire Inc', department='Research and Development', employee_id=558987515, vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2007)
# M(ssn=870931121, first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew', last_updated=datetime.datetime(2017, 3, 3, 3, 45, 30), created=datetime.datetime(2016, 6, 21, 17, 1, 53), employer='Morissette, Rowe and Muller', department='Engineering', employee_id=739912953, vehicle_make='Mitsubishi', vehicle_model='Pajero', model_year=1998)
# M(ssn=871993191, first_name='Susann', last_name='Walrond', gender='Female', language='Amharic', last_updated=datetime.datetime(2017, 5, 8, 8, 24, 12), created=datetime.datetime(2016, 2, 27, 15, 43, 26), employer='Lueilwitz, Stokes and Kassulke', department='Marketing', employee_id=161937114, vehicle_make='Toyota', vehicle_model='Sienna', model_year=2000)
# M(ssn=872189267, first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese', last_updated=datetime.datetime(2018, 3, 22, 21, 11, 58), created=datetime.datetime(2016, 4, 27, 3, 27, 17), employer='Glover, Jacobs and Heidenreich', department='Sales', employee_id=721577952, vehicle_make='Audi', vehicle_model='A4', model_year=2010)
# M(ssn=872491288, first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish', last_updated=datetime.datetime(2017, 12, 6, 2, 19, 8), created=datetime.datetime(2016, 6, 10, 10, 5, 19), employer='Cummings-Mertz', department='Sales', employee_id=782291834, vehicle_make='Acura', vehicle_model='Integra', model_year=1997)
# M(ssn=873364733, first_name='Locke', last_name='Staries', gender='Male', language='Moldovan', last_updated=datetime.datetime(2017, 7, 23, 1, 30, 5), created=datetime.datetime(2016, 7, 8, 7, 10, 52), employer='Wilderman-Grimes', department='Engineering', employee_id=396055619, vehicle_make='Austin', vehicle_model='Mini Cooper', model_year=1964)
# M(ssn=875189454, first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu', last_updated=datetime.datetime(2017, 3, 14, 4, 45, 19), created=datetime.datetime(2016, 8, 19, 18, 23, 57), employer='Schultz-Medhurst', department='Support', employee_id=566050344, vehicle_make='Mitsubishi', vehicle_model='Diamante', model_year=1993)
# M(ssn=875750495, first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish', last_updated=datetime.datetime(2017, 12, 3, 21, 27, 47), created=datetime.datetime(2016, 6, 12, 12, 36, 44), employer='Wunsch-Gleason', department='Services', employee_id=283015726, vehicle_make='Hyundai', vehicle_model='Tiburon', model_year=2000)
# M(ssn=881195974, first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho', last_updated=datetime.datetime(2018, 2, 4, 17, 29, 28), created=datetime.datetime(2016, 10, 5, 21, 57, 12), employer='Daugherty, Gislason and Kreiger', department='Training', employee_id=255973403, vehicle_make='Infiniti', vehicle_model='G', model_year=2004)
# M(ssn=881887308, first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga', last_updated=datetime.datetime(2017, 8, 11, 11, 40, 28), created=datetime.datetime(2016, 1, 18, 12, 51), employer="O'Connell, Raynor and Veum", department='Sales', employee_id=160843654, vehicle_make='Subaru', vehicle_model='SVX', model_year=1994)
# M(ssn=881957180, first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian', last_updated=datetime.datetime(2018, 1, 29, 16, 6, 26), created=datetime.datetime(2016, 11, 24, 12, 12, 51), employer='Schumm Inc', department='Services', employee_id=188360445, vehicle_make='BMW', vehicle_model='M6', model_year=2009)
# M(ssn=887417878, first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil', last_updated=datetime.datetime(2017, 3, 27, 13, 38, 47), created=datetime.datetime(2016, 9, 14, 9, 26, 53), employer='Ziemann, Denesik and Casper', department='Research and Development', employee_id=716097002, vehicle_make='Lexus', vehicle_model='GS', model_year=2013)
# M(ssn=887839002, first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin', last_updated=datetime.datetime(2017, 12, 19, 6, 24, 25), created=datetime.datetime(2016, 5, 30, 2, 40, 28), employer='Terry and Sons', department='Research and Development', employee_id=69390159, vehicle_make='Audi', vehicle_model='S6', model_year=2011)
# M(ssn=888507008, first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha', last_updated=datetime.datetime(2018, 3, 6, 16, 54, 20), created=datetime.datetime(2016, 6, 9, 11, 3, 40), employer='Herzog, Stehr and Quitzon', department='Engineering', employee_id=385385705, vehicle_make='Nissan', vehicle_model='Armada', model_year=2008)
# M(ssn=888537684, first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian', last_updated=datetime.datetime(2017, 9, 5, 0, 30), created=datetime.datetime(2016, 2, 12, 1, 35, 59), employer='Collier, Hilll and Hagenes', department='Training', employee_id=156651242, vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=1991)
# M(ssn=888824928, first_name='Billye', last_name='Legat', gender='Female', language='Icelandic', last_updated=datetime.datetime(2017, 12, 8, 14, 2, 48), created=datetime.datetime(2016, 11, 9, 10, 4, 16), employer='Reynolds, Nicolas and Morar', department='Engineering', employee_id=483998718, vehicle_make='Volvo', vehicle_model='S60', model_year=2005)
# M(ssn=890289962, first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua', last_updated=datetime.datetime(2018, 1, 6, 9, 34, 59), created=datetime.datetime(2016, 2, 22, 15, 24, 59), employer='Heller, Kihn and Bartoletti', department='Research and Development', employee_id=569393666, vehicle_make='GMC', vehicle_model='Savana 1500', model_year=2000)
# M(ssn=893120901, first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya', last_updated=datetime.datetime(2018, 3, 27, 1, 24, 58), created=datetime.datetime(2016, 6, 14, 2, 41, 25), employer='Christiansen LLC', department='Sales', employee_id=661175841, vehicle_make='Lotus', vehicle_model='Esprit', model_year=1991)
# M(ssn=893177318, first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz', last_updated=datetime.datetime(2017, 7, 23, 7, 11, 51), created=datetime.datetime(2016, 2, 28, 8, 1, 12), employer='Orn Inc', department='Human Resources', employee_id=384356300, vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=1995)
# M(ssn=894810628, first_name='Ree', last_name='Mordue', gender='Female', language='Tswana', last_updated=datetime.datetime(2017, 3, 7, 4, 8, 28), created=datetime.datetime(2016, 7, 9, 11, 43, 17), employer='Flatley, Senger and Bernier', department='Services', employee_id=722633200, vehicle_make='Kia', vehicle_model='Sedona', model_year=2012)
# M(ssn=895261658, first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic', last_updated=datetime.datetime(2017, 4, 1, 22, 22, 5), created=datetime.datetime(2016, 11, 22, 6, 57, 45), employer='Hilll, Kunze and Beer', department='Human Resources', employee_id=904168298, vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=2003)
# M(ssn=895265515, first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho', last_updated=datetime.datetime(2017, 5, 13, 5, 52, 27), created=datetime.datetime(2016, 3, 24, 7, 34, 14), employer='Franecki LLC', department='Services', employee_id=637802530, vehicle_make='Acura', vehicle_model='TL', model_year=1999)
# M(ssn=897767070, first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali', last_updated=datetime.datetime(2017, 11, 27, 19, 4, 22), created=datetime.datetime(2016, 12, 12, 7, 39, 48), employer='Reilly-Jakubowski', department='Marketing', employee_id=776363112, vehicle_make='BMW', vehicle_model='X3', model_year=2011)
# M(ssn=898033165, first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic', last_updated=datetime.datetime(2017, 6, 1, 19, 18, 49), created=datetime.datetime(2016, 7, 20, 21, 40, 2), employer='Bins-Gerhold', department='Sales', employee_id=899965641, vehicle_make='Toyota', vehicle_model='Xtra', model_year=1994)
# M(ssn=898868860, first_name='Hershel', last_name='Few', gender='Male', language='Gagauz', last_updated=datetime.datetime(2017, 7, 3, 14, 27, 26), created=datetime.datetime(2016, 11, 23, 23, 34, 17), employer='Olson-Johnson', department='Support', employee_id=367761827, vehicle_make='Lotus', vehicle_model='Esprit', model_year=2003)
# M(ssn=899091766, first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino', last_updated=datetime.datetime(2017, 7, 31, 2, 26, 57), created=datetime.datetime(2016, 10, 27, 18, 41, 56), employer='Cronin LLC', department='Services', employee_id=838730953, vehicle_make='Toyota', vehicle_model='Camry', model_year=2012)
# M(ssn=899397179, first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek', last_updated=datetime.datetime(2017, 8, 2, 13, 32, 33), created=datetime.datetime(2016, 7, 27, 12, 47, 5), employer='Little-Hansen', department='Business Development', employee_id=458154226, vehicle_make='Infiniti', vehicle_model='FX', model_year=2006)
# M(ssn=899397378, first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian', last_updated=datetime.datetime(2017, 3, 27, 19, 31, 32), created=datetime.datetime(2016, 9, 4, 15, 9, 22), employer="Christiansen, Ondricka and O'Connell", department='Marketing', employee_id=327034344, vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=1999)
# M(ssn=899476116, first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum', last_updated=datetime.datetime(2017, 6, 10, 11, 20, 41), created=datetime.datetime(2016, 4, 29, 12, 25, 23), employer='Bednar LLC', department='Support', employee_id=166342889, vehicle_make='Volkswagen', vehicle_model='Phaeton', model_year=2005)

# %% [markdown]
# # Finding vehicle make owned the most by males in data

# %%
print(Counter([ getattr(entry, 'vehicle_make') for entry in itr  if getattr(entry, 'gender') == 'Male']))
# Out:
# Counter({'Ford': 40, 'Chevrolet': 30, 'GMC': 28, 'Mitsubishi': 28, 'Dodge': 22, 'Toyota': 21, 'Mercedes-Benz': 19, 'Volkswagen': 16, 'Audi': 14, 'Buick': 13, 'Mazda': 13, 'BMW': 12, 'Pontiac': 11, 'Mercury': 11, 'Volvo': 10, 'Cadillac': 9, 'Honda': 9, 'Subaru': 8, 'Hyundai': 8, 'Saab': 8, 'Acura': 7, 'Infiniti': 7, 'Jeep': 7, 'Lexus': 6, 'Nissan': 6, 'Oldsmobile': 5, 'Lincoln': 5, 'Kia': 5, 'Lotus': 5, 'Jaguar': 4, 'Plymouth': 4, 'Porsche': 4, 'Lamborghini': 4, 'Aston Martin': 3, 'Isuzu': 3, 'Maserati': 3, 'Chrysler': 3, 'Saturn': 3, 'Bentley': 3, 'Land Rover': 3, 'Maybach': 2, 'Panoz': 2, 'Geo': 2, 'Suzuki': 2, 'Scion': 1, 'Jensen': 1, 'Smart': 1, 'Rolls-Royce': 1, 'Corbin': 1, 'Daewoo': 1, 'Aptera': 1, 'Eagle': 1, 'Austin': 1})

# %%
male_vmaker_counts = Counter([ getattr(entry, 'vehicle_make') for entry in itr  if getattr(entry, 'gender') == 'Male'])

# %%
max_male_vmaker_counts = max(male_vmaker_counts.values())
for entry in male_vmaker_counts:
    if male_vmaker_counts[entry] == max_male_vmaker_counts:
        print(entry,male_vmaker_counts[entry])
# Out:
# Ford 40

# %% [markdown]
# # Finding vehicle make owned the most by females in data

# %%
print(Counter([ getattr(entry, 'vehicle_make') for entry in itr  if getattr(entry, 'gender') == 'Female']))
# Out:
# Counter({'Chevrolet': 42, 'Ford': 42, 'GMC': 22, 'Mitsubishi': 22, 'Toyota': 20, 'Mercedes-Benz': 17, 'Dodge': 17, 'Lexus': 15, 'Pontiac': 14, 'Volvo': 13, 'Audi': 13, 'Mazda': 13, 'BMW': 12, 'Nissan': 12, 'Suzuki': 12, 'Buick': 11, 'Volkswagen': 10, 'Acura': 9, 'Kia': 9, 'Infiniti': 9, 'Land Rover': 8, 'Honda': 8, 'Oldsmobile': 8, 'Chrysler': 6, 'Cadillac': 6, 'Subaru': 6, 'Jeep': 5, 'Mercury': 5, 'Lotus': 5, 'Bentley': 4, 'Hyundai': 4, 'Lincoln': 4, 'Isuzu': 3, 'Plymouth': 3, 'Saturn': 3, 'Porsche': 3, 'Saab': 3, 'Jaguar': 3, 'Scion': 2, 'Aston Martin': 2, 'Lamborghini': 2, 'Bugatti': 1, 'Rolls-Royce': 1, 'Eagle': 1, 'Geo': 1, 'Morgan': 1, 'Austin': 1, 'Panoz': 1})

# %%
female_vmaker_counts = Counter([ getattr(entry, 'vehicle_make') for entry in itr  if getattr(entry, 'gender') == 'Female'])

# %%
max_female_vmaker_counts = max(female_vmaker_counts.values())
for entry in female_vmaker_counts:
    if female_vmaker_counts[entry] == max_female_vmaker_counts:
        print(entry,female_vmaker_counts[entry])
# Out:
# Chevrolet 42
# Ford 42
